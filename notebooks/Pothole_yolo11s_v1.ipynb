# %% [markdown]
# <a href="https://colab.research.google.com/github/kibwale/nipe_macho/blob/main/notebooks/Pothole_yolo11s_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Pothole Detection AI — Training Notebook
# ### Built on YOLO11 | Chepalungu + RDD2020 Datasets
#
# ---
#
# This notebook trains an AI model to detect potholes in road images.
# It is designed so that:
# - ✅ You can stop and resume training at any time without losing progress
# - ✅ Every cell explains what it does before running
# - ✅ Problems are caught early before you waste time
# - ✅ All results are saved to Google Drive automatically
#
# ## 🗺️ Notebook Map
#
# | Section | What It Does |
# |---|---|
# | 0. Setup | Install packages, load keys, mount Drive |
# | 1. Pre-Flight Checks | Verify GPU, keys, Drive BEFORE running |
# | 2. Download Data | Get Chepalungu + RDD2020 datasets |
# | 3. Prepare Data | Convert formats, clean labels, merge |
# | 4. Train | Train YOLO11 with auto-save to Drive |
# | 5. Resume | How to continue if Colab disconnects |
# | 6. Evaluate | See accuracy numbers and charts |
# | 7. Test | Run on new images and see detections |
#
# ## ⚠️ One Rule
# **Run cells from top to bottom, one at a time.
# Never skip a cell. Each one builds on the previous.**

# %%
# ============================================================
# SECTION 0: INSTALL PACKAGES AND LOAD UTILITIES
# ============================================================
#
# What this cell does, in order:
#   1. Installs the Python packages we need
#   2. Downloads our helper code from GitHub (utils.py)
#   3. VERIFIES that download actually worked (this is the
#      part that kept failing silently before)
#   4. Loads every helper function into memory
#   5. Sets HOME — the base folder every other cell uses
#   6. Confirms the GPU/CPU status
#
# IMPORTANT: If ANY step below prints a ❌, STOP. Do not run
# any other cell until you fix that ❌ and re-run this cell
# from the top. Every later section depends on this one
# finishing completely.
# ============================================================

import os

print("=" * 60)
print("STEP 1/5 — Installing packages (takes ~60 seconds)")
print("=" * 60)
get_ipython().run_line_magic(
    'pip', 'install "ultralytics<=8.3.40" supervision roboflow kaggle pyyaml -q'
)
print("✅ Packages installed\n")

print("=" * 60)
print("STEP 2/5 — Downloading utils.py from GitHub")
print("=" * 60)

GITHUB_USERNAME = "mwangikabacho254"   # ← this is already set correctly for you
UTILS_URL = f"https://raw.githubusercontent.com/{GITHUB_USERNAME}/pothole-utils/main/utils.py"

os.chdir("/content")
exit_code = os.system(f"wget -q {UTILS_URL} -O utils.py")

if not os.path.exists("utils.py"):
    raise RuntimeError(
        "❌ utils.py did not download at all. Check your internet "
        "connection and that the GitHub repo 'pothole-utils' is Public."
    )

with open("utils.py") as f:
    content = f.read()

if len(content) < 500 or "404" in content[:200] or "<html" in content[:200].lower():
    raise RuntimeError(
        f"❌ utils.py downloaded but looks wrong (size={len(content)} bytes).\n"
        f"   URL used: {UTILS_URL}\n"
        f"   Go check that this URL opens correctly in a browser tab."
    )

if "def run_all_checks" not in content:
    raise RuntimeError(
        "❌ utils.py downloaded but is missing expected functions.\n"
        "   Your GitHub file may be outdated — recopy the full utils.py "
        "content into your GitHub repo and commit again."
    )

print(f"✅ utils.py downloaded correctly ({len(content)} bytes)\n")

print("=" * 60)
print("STEP 3/5 — Loading utility functions into memory")
print("=" * 60)

import importlib
import sys

# Force a clean re-import even if an old broken version got cached earlier
if "utils" in sys.modules:
    del sys.modules["utils"]

import utils
importlib.reload(utils)
from utils import *

# Hard proof it actually worked — don't just trust the print statement
assert "run_all_checks" in globals(), "run_all_checks still not loaded — stop and ask for help."
assert "check_gpu" in globals(), "check_gpu still not loaded — stop and ask for help."
assert "clean_all_labels" in globals(), "clean_all_labels still not loaded — stop and ask for help."

print("✅ All utility functions confirmed loaded (run_all_checks, check_gpu, "
      "clean_all_labels, and others)\n")

print("=" * 60)
print("STEP 4/5 — Setting HOME directory")
print("=" * 60)
HOME = "/content"
os.chdir(HOME)
print(f"✅ HOME = {HOME}\n")

print("=" * 60)
print("STEP 5/5 — Checking software + hardware")
print("=" * 60)
os.system("yolo settings sync=False")

import ultralytics
ultralytics.checks()

import torch
if torch.cuda.is_available():
    print(f"\n✅ GPU detected: {torch.cuda.get_device_name(0)}")
else:
    print("\n⚠️  NO GPU DETECTED — you are running on CPU.")
    print("   Training will be extremely slow or may not work at all.")
    print("   FIX: Runtime → Change runtime type → T4 GPU → Save")
    print("   (This will restart your session — you'll need to re-run this cell after.)")

print("\n" + "=" * 60)
print("🎉 SECTION 0 COMPLETE — safe to continue to Section 0B")
print("=" * 60)
# Out:
# Ultralytics 8.3.40 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 46.9/112.6 GB disk)
#
# ✅ GPU detected: Tesla T4
#
# ============================================================
# 🎉 SECTION 0 COMPLETE — safe to continue to Section 0B
# ============================================================

# %% [markdown]
#  ## Mount Google Drive

# %%
# ============================================================
# MOUNT GOOGLE DRIVE
# ============================================================
#
# WHY: Google Drive is your safety net.
# Colab sessions end after 12 hours (or if you close the tab).
# When that happens, everything in /content disappears.
# By saving to Drive, your trained model weights survive
# even if Colab shuts down mid-training.
#
# When you run this cell, a popup will ask you to sign in
# to Google. Click "Connect to Google Drive" and allow access.
# ============================================================

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# Create the folder structure on Drive
DRIVE_ROOT    = "/content/drive/MyDrive/PotholeAI"
DRIVE_RUNS    = f"{DRIVE_ROOT}/runs"
DRIVE_DATA    = f"{DRIVE_ROOT}/datasets"

os.makedirs(DRIVE_RUNS, exist_ok=True)
os.makedirs(DRIVE_DATA, exist_ok=True)

print("✅ Google Drive mounted")
print(f"   Your runs will be saved to: {DRIVE_RUNS}")
print(f"   Your datasets backed up to: {DRIVE_DATA}")
# Out:
# Mounted at /content/drive
# ✅ Google Drive mounted
#    Your runs will be saved to: /content/drive/MyDrive/PotholeAI/runs
#    Your datasets backed up to: /content/drive/MyDrive/PotholeAI/datasets

# %% [markdown]
# **Load API Keys**

# %%
# ============================================================
# LOAD API KEYS FROM COLAB SECRETS
# ============================================================
#
# API keys are like passwords. We NEVER type them directly
# into the notebook because:
#   - Someone could see them if you share the notebook
#   - They could end up in version history
#
# Instead we use Colab Secrets (the 🔑 icon in the left sidebar).
# If any key is missing, the cell will tell you exactly what to add.
#
# HOW TO ADD A SECRET:
#   1. Click the 🔑 key icon in the left sidebar
#   2. Click "+ Add new secret"
#   3. Type the Name exactly as shown below
#   4. Paste your key as the Value
#   5. Toggle "Notebook access" to ON
#
# Required secrets:
#   ROBOFLOW_API_KEY  → roboflow.com → Settings → Roboflow API → Copy
#   KAGGLE_USERNAME   → your Kaggle username (shown on kaggle.com/me)
#   KAGGLE_KEY        → kaggle.com → Settings → API → Create New Token
#                       open kaggle.json, copy the "key" value only
# ============================================================

from google.colab import userdata
import json

# Load Roboflow key
ROBOFLOW_API_KEY = userdata.get('ROBOFLOW_API_KEY')
print("✅ Roboflow API key loaded")

# Load Kaggle credentials and write to the location Kaggle CLI expects
KAGGLE_USERNAME = userdata.get('KAGGLE_USERNAME')
KAGGLE_KEY      = userdata.get('KAGGLE_KEY')

os.makedirs('/root/.kaggle', exist_ok=True)
with open('/root/.kaggle/kaggle.json', 'w') as f:
    json.dump({"username": KAGGLE_USERNAME, "key": KAGGLE_KEY}, f)
os.system("chmod 600 /root/.kaggle/kaggle.json")

print(f"✅ Kaggle API key configured — username: {KAGGLE_USERNAME}")
print("\n🎉 All keys loaded. You are ready to continue.")
# Out:
# ✅ Roboflow API key loaded
# ✅ Kaggle API key configured — username: Mwangi kabacho
#
# 🎉 All keys loaded. You are ready to continue.

# %% [markdown]
# **Pre-Flight Checks**

# %%
# ============================================================
# SECTION 1: PRE-FLIGHT CHECKS
# ============================================================
#
# This is like a pilot's checklist before takeoff.
# We verify EVERYTHING is working BEFORE downloading
# or processing any data.
#
# If anything is RED (❌), fix it before running Section 2.
# The cell tells you exactly what to fix.
#
# Checks performed:
#   ✅ GPU is T4 (needed for fast training)
#   ✅ All 3 API keys are available
#   ✅ Google Drive is mounted (for saving weights)
# ============================================================

print("Running pre-flight checks...\n")
all_ok = run_all_checks()

if all_ok:
    print("\n🚀 All systems go. Proceed to Section 2.")
else:
    print("\n🛑 Fix the issues above, then re-run this cell.")
    print("   Do NOT continue to Section 2 until all checks pass.")
# Out:
# Running pre-flight checks...
#
# =======================================================
#   PRE-FLIGHT CHECKS
# =======================================================
# ✅ GPU: Tesla T4 confirmed
# Checking Colab Secrets:
#   ✅ ROBOFLOW_API_KEY — found
#   ✅ KAGGLE_USERNAME — found
#   ✅ KAGGLE_KEY — found
# ✅ Google Drive mounted
# =======================================================
# ✅ ALL CHECKS PASSED — Safe to continue
#
# 🚀 All systems go. Proceed to Section 2.

# %% [markdown]
# **Download Chepalungu Dataset**

# %%
# ============================================================
# SECTION 2A: DOWNLOAD CHEPALUNGU DATASET
# ============================================================
#
# The Chepalungu dataset contains photos of potholes taken
# on Kenyan roads. It was collected specifically for this project.
# It is stored in Roboflow (a dataset management platform).
#
# The Roboflow SDK downloads it directly into Colab
# in YOLO format — which means:
#   - Images in a folder called "images/"
#   - Labels in a folder called "labels/"
#   - Each label is a .txt file with one line per pothole
#
# This cell checks if the dataset already exists before
# downloading — so re-running the notebook won't re-download.
# ============================================================

from roboflow import Roboflow

CHEPALUNGU_DIR = f"{HOME}/datasets/chepalungu-1"

if os.path.exists(CHEPALUNGU_DIR):
    print(f"✅ Chepalungu dataset already downloaded at: {CHEPALUNGU_DIR}")
    print("   Skipping download.")
else:
    print("⬇️  Downloading Chepalungu dataset from Roboflow...")
    rf         = Roboflow(api_key=ROBOFLOW_API_KEY)
    ws         = rf.workspace("nipemacho")
    project    = ws.project("chepalungu")
    version    = project.version(1)

    os.makedirs(f"{HOME}/datasets", exist_ok=True)
    os.chdir(f"{HOME}/datasets")

    dataset    = version.download("yolov11")
    CHEPALUNGU_DIR = dataset.location
    print(f"✅ Downloaded to: {CHEPALUNGU_DIR}")

# Show what we got
print("\n📦 Chepalungu dataset contents:")
for split in ['train', 'valid', 'test']:
    img_dir = os.path.join(CHEPALUNGU_DIR, split, 'images')
    if os.path.exists(img_dir):
        n = len(os.listdir(img_dir))
        print(f"   {split:>5}: {n} images")

os.chdir(HOME)
# Out:
# ⬇️  Downloading Chepalungu dataset from Roboflow...
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in chepalungu-1 to yolov11:: 100%|██████████| 14551/14551 [00:00<00:00, 24629.40it/s]
# Extracting Dataset Version Zip to chepalungu-1 in yolov11:: 100%|██████████| 527/527 [00:00<00:00, 5171.18it/s]
# ✅ Downloaded to: /content/datasets/chepalungu-1
#
# 📦 Chepalungu dataset contents:
#    train: 183 images
#    valid: 52 images
#     test: 26 images

# %% [markdown]
# **Download RDD2020 Dataset**

# %%
# ============================================================
# SECTION 2B: DOWNLOAD RDD2020 DATASET
# ============================================================
#
# RDD2020 = Road Damage Detection 2020
# This is a large international dataset with road damage images
# from Japan, India, and Czech Republic.
#
# WHY we use it:
#   The Chepalungu dataset has ~260 images.
#   RDD2020 adds 6,000+ more diverse images.
#   More images = better model.
#
# The RDD2020 dataset uses XML annotations (Pascal VOC format).
# In Section 3 we will convert them to YOLO format.
#
# This is a 1.4GB download. It checks if already downloaded.
# On Colab's fast connection it takes ~20 seconds.
# ============================================================

RDD_DIR  = "/content/rdd2020"
RDD_ZIP  = "/content/rdd2020.zip"

if os.path.exists(RDD_DIR) and os.listdir(RDD_DIR):
    print(f"✅ RDD2020 already downloaded at: {RDD_DIR}")
    print("   Skipping download.")
else:
    print("⬇️  Downloading RDD2020 dataset from Kaggle (1.4GB)...")
    print("   This takes about 20 seconds on Colab's connection.")
    os.makedirs(RDD_DIR, exist_ok=True)
    os.system(f"kaggle datasets download -d ziedkelboussi/rdd2020-dataset "
              f"-p {RDD_DIR} --unzip")
    print("✅ RDD2020 downloaded and extracted")

# Show folder structure
print("\n📦 RDD2020 folder structure:")
for country in ['Czech', 'India', 'Japan']:
    xml_dir = f"{RDD_DIR}/train/{country}/annotations/xmls"
    img_dir = f"{RDD_DIR}/train/{country}/images"
    if os.path.exists(xml_dir):
        n_xml = len(list(Path(xml_dir).glob('*.xml')))
        n_img = len(list(Path(img_dir).glob('*.jpg')))
        print(f"   {country}: {n_img} images, {n_xml} annotations")
    else:
        print(f"   {country}: ⚠️  folder not found")
# Out:
# ⬇️  Downloading RDD2020 dataset from Kaggle (1.4GB)...
#    This takes about 20 seconds on Colab's connection.
# ✅ RDD2020 downloaded and extracted
#
# 📦 RDD2020 folder structure:
#    Czech: 2829 images, 2829 annotations
#    India: 7706 images, 7706 annotations
#    Japan: 10506 images, 10506 annotations

# %% [markdown]
# **Convert RDD2020 XML to YOLO**

# %%
# ============================================================
# SECTION 3A: CONVERT RDD2020 ANNOTATIONS TO YOLO FORMAT
# ============================================================
#
# The RDD2020 dataset labels damage in 10 categories:
#   D00, D01, D10, D11, D20, D40, D43, D44, D50, D0w0
#
# We only want potholes. In RDD2020, potholes = D40.
# We will:
#   1. Read each XML file
#   2. Keep ONLY annotations labelled "D40"
#   3. Convert the bounding box to YOLO format
#   4. Save as .txt files in a "labels" folder next to "images"
#
# After this, both Chepalungu AND RDD2020 will be in the same
# YOLO format, ready to be merged.
# ============================================================

print("Converting RDD2020 XML annotations → YOLO format")
print("Keeping only D40 (pothole) class\n")

TARGET_CLASS = "D40"
total_positive = 0
total_negative = 0

for country in ['Czech', 'India', 'Japan']:
    xml_dir = f"{RDD_DIR}/train/{country}/annotations/xmls"
    lbl_dir = f"{RDD_DIR}/train/{country}/labels"

    if not os.path.exists(xml_dir):
        print(f"⚠️  {country}: no annotations folder, skipping")
        continue

    converted, _, boxes = convert_xml_folder_to_yolo(
        xml_dir   = xml_dir,
        img_dir   = f"{RDD_DIR}/train/{country}/images",
        out_dir   = lbl_dir,
        target_classes = [TARGET_CLASS],
        class_id  = 0
    )

    # Count positives (files with at least one box)
    positives = sum(
        1 for f in Path(lbl_dir).glob('*.txt')
        if open(f).read().strip()
    )
    negatives = converted - positives
    total_positive += positives
    total_negative += negatives
    print(f"   {country}: {positives} with potholes, {negatives} without")

print(f"\n✅ Total: {total_positive} images with potholes")
print(f"   (The {total_negative} images without are kept as background)")
# Out:
# Converting RDD2020 XML annotations → YOLO format
# Keeping only D40 (pothole) class
#
#   Converted 2829 XML files → 197 YOLO boxes
#    Czech: 154 with potholes, 2675 without
#   Converted 7706 XML files → 3187 YOLO boxes
#    India: 1530 with potholes, 6176 without
#   Converted 10506 XML files → 2243 YOLO boxes
#    Japan: 1390 with potholes, 9116 without
#
# ✅ Total: 3074 images with potholes
#    (The 17967 images without are kept as background)

# %% [markdown]
# **Clean All Labels**

# %%
# ============================================================
# SECTION 3B: CLEAN ALL LABEL FILES
# ============================================================
#
# Why do we need to clean labels?
#
# The Chepalungu dataset was annotated using polygons in Roboflow.
# Polygons look like: 0 x1 y1 x2 y2 x3 y3 x4 y4 ...
# YOLO needs bounding boxes: 0 cx cy w h  (exactly 5 values)
#
# If we skip this step, YOLO silently ignores polygon lines
# during training — which is why you were getting 324 images
# instead of 6000+. The images were there but the annotations
# were being ignored.
#
# This cell:
#   - Converts every polygon line to a bounding box
#   - Forces all class IDs to 0 (single class: pothole)
#   - Removes any lines that are genuinely corrupt
# ============================================================

print("Cleaning Chepalungu labels (fixing polygons → boxes)...")
chep_stats = clean_all_labels(CHEPALUNGU_DIR, force_class=0)

print("\nCleaning RDD2020 labels (ensuring consistent format)...")
rdd_stats = clean_all_labels(RDD_DIR, force_class=0)

print(f"\n✅ Label cleaning complete")
print(f"   Chepalungu: {chep_stats['fixed_polygons']} polygon lines converted")
print(f"   RDD2020:    {rdd_stats['fixed_polygons']} polygon lines converted")
# Out:
# Cleaning Chepalungu labels (fixing polygons → boxes)...
#   Files cleaned       : 263
#   Total boxes kept    : 495
#   Polygon lines fixed : 500
#
# Cleaning RDD2020 labels (ensuring consistent format)...
#   Files cleaned       : 21041
#   Total boxes kept    : 5627
#   Polygon lines fixed : 0
#
# ✅ Label cleaning complete
#    Chepalungu: 500 polygon lines converted
#    RDD2020:    0 polygon lines converted

# %% [markdown]
# **Build Combined Dataset**

# %%
# ============================================================
# SECTION 3C: BUILD COMBINED DATASET
# ============================================================
#
# Now we merge Chepalungu + RDD2020 into one unified dataset.
#
# For RDD2020 we balance the data first:
#   - Keep ALL positive images (have potholes): 3,074
#   - Keep 1 negative per positive (no potholes): ~3,074
#   - Total from RDD: ~6,148 selected from 21,000
#
# Then we split everything into:
#   - 80% training   (model learns from this)
#   - 10% validation (we check progress during training)
#   - 10% test       (final accuracy test, model never sees this)
#
# We add prefixes to filenames so there are no name collisions:
#   kenya_IMG_001.jpg   ← from Chepalungu
#   rdd_Czech_001.jpg   ← from RDD2020
# ============================================================

COMBINED_DIR = f"{HOME}/datasets/combined"

if os.path.exists(COMBINED_DIR) and os.path.exists(f"{COMBINED_DIR}/data.yaml"):
    print(f"✅ Combined dataset already exists at: {COMBINED_DIR}")
    print("   Skipping merge step.")
else:
    print("Building combined dataset from Chepalungu + RDD2020...\n")

    # ── Balance RDD2020 first ─────────────────────────────────
    # Keep all positives + equal number of negatives per country
    rdd_sources = []
    for country in ['Czech', 'India', 'Japan']:
        img_dir = f"{RDD_DIR}/train/{country}/images"
        lbl_dir = f"{RDD_DIR}/train/{country}/labels"
        if not os.path.exists(img_dir):
            continue

        positives = [f for f in Path(lbl_dir).glob('*.txt')
                     if open(f).read().strip()]
        negatives = [f for f in Path(lbl_dir).glob('*.txt')
                     if not open(f).read().strip()]

        # 1 negative per positive
        n_keep = min(len(negatives), len(positives))
        random.seed(42)
        kept_neg = random.sample(negatives, n_keep)

        selected = positives + kept_neg
        random.shuffle(selected)

        # Split 80/10/10
        n = len(selected)
        n_train = int(n * 0.8)
        n_val   = int(n * 0.1)
        splits  = {
            'train': selected[:n_train],
            'valid': selected[n_train:n_train+n_val],
            'test':  selected[n_train+n_val:]
        }

        for split, files in splits.items():
            dst_img = f"{COMBINED_DIR}/{split}/images"
            dst_lbl = f"{COMBINED_DIR}/{split}/labels"
            os.makedirs(dst_img, exist_ok=True)
            os.makedirs(dst_lbl, exist_ok=True)
            for lbl_path in files:
                stem = lbl_path.stem
                img_src = f"{img_dir}/{stem}.jpg"
                if not os.path.exists(img_src):
                    continue
                prefix = country.lower()
                shutil.copy(img_src,
                            f"{dst_img}/{prefix}_{stem}.jpg")
                shutil.copy(str(lbl_path),
                            f"{dst_lbl}/{prefix}_{stem}.txt")

        total = len(selected)
        print(f"  {country}: {len(positives)} positive + {n_keep} negative = {total} selected")

    # ── Copy Chepalungu into combined ─────────────────────────
    print("\n  Adding Chepalungu (Kenya) images:")
    for split, dst_split in [('train','train'),('valid','valid'),('test','test')]:
        src_img = f"{CHEPALUNGU_DIR}/{split}/images"
        src_lbl = f"{CHEPALUNGU_DIR}/{split}/labels"
        dst_img = f"{COMBINED_DIR}/{dst_split}/images"
        dst_lbl = f"{COMBINED_DIR}/{dst_split}/labels"
        n = copy_split(src_img, src_lbl, dst_img, dst_lbl, prefix='kenya')
        print(f"    {split}: {n} images")

    # ── Write data.yaml with ABSOLUTE paths ───────────────────
    import yaml
    yaml_path = f"{COMBINED_DIR}/data.yaml"
    with open(yaml_path, 'w') as f:
        yaml.dump({
            'train': f"{COMBINED_DIR}/train/images",
            'val':   f"{COMBINED_DIR}/valid/images",
            'test':  f"{COMBINED_DIR}/test/images",
            'nc':    1,
            'names': ['pothole']
        }, f)
    print(f"\n✅ data.yaml written with absolute paths")

# ── Always verify counts ─────────────────────────────────────
print("\nFinal dataset totals:")
for split in ['train', 'valid', 'test']:
    img_dir = f"{COMBINED_DIR}/{split}/images"
    lbl_dir = f"{COMBINED_DIR}/{split}/labels"
    if os.path.exists(img_dir):
        n_img = len(os.listdir(img_dir))
        n_lbl = len(os.listdir(lbl_dir))
        print(f"  {split:>5}: {n_img} images, {n_lbl} labels")
# Out:
# Building combined dataset from Chepalungu + RDD2020...
#
#   Czech: 154 positive + 154 negative = 308 selected
#   India: 1530 positive + 1530 negative = 3060 selected
#   Japan: 1390 positive + 1390 negative = 2780 selected
#
#   Adding Chepalungu (Kenya) images:
#     train: 183 images
#     valid: 52 images
#     test: 26 images
#
# ✅ data.yaml written with absolute paths
#
# Final dataset totals:
#   train: 5101 images, 5101 labels
#   valid: 666 images, 666 labels
#    test: 642 images, 642 labels

# %% [markdown]
# **Final Integrity Check**

# %%
# ============================================================
# SECTION 3D: FINAL DATA INTEGRITY CHECK
# ============================================================
#
# Before we start training (which takes 30-40 minutes),
# we do one final check on the combined dataset.
#
# This confirms:
#   ✅ data.yaml paths are correct and exist
#   ✅ Image and label counts match
#   ✅ Total bounding boxes are sensible
#
# If you see large numbers here (5000+ training images),
# the merge worked correctly.
# If you see small numbers (300-400), something went wrong
# — stop and re-run Section 3C.
# ============================================================

DATA_YAML = f"{COMBINED_DIR}/data.yaml"

print("Running final dataset integrity check...\n")
ok = check_dataset(COMBINED_DIR)

# Show the data.yaml so you can see the paths are absolute
print("\n=== Contents of data.yaml ===")
with open(DATA_YAML) as f:
    print(f.read())

if ok:
    print("✅ Dataset is clean and ready for training.")
    print("   Proceed to Section 4 to train the model.")
else:
    print("❌ Problems detected. Fix them before training.")
# Out:
# Running final dataset integrity check...
#
# =======================================================
# DATASET INTEGRITY CHECK
# =======================================================
#   ✅ train: 5101 images | 5101 labels | 4852 boxes
#   ✅   val: 666 images | 666 labels | 687 boxes
#   ✅  test: 642 images | 642 labels | 576 boxes
# =======================================================
#   Classes: 1 → ['pothole']
# =======================================================
#
# === Contents of data.yaml ===
# names:
# - pothole
# nc: 1
# test: /content/datasets/combined/test/images
# train: /content/datasets/combined/train/images
# val: /content/datasets/combined/valid/images
#
# ✅ Dataset is clean and ready for training.
#    Proceed to Section 4 to train the model.

# %% [markdown]
# **Train the Model**

# %%
# ============================================================
# SECTION 4: TRAIN THE YOLO11 MODEL
# ============================================================
#
# This is the main event. YOLO11 will learn to detect potholes.
#
# What happens during training:
#   - The model sees your training images one by one
#   - For each image, it makes a prediction
#   - It compares its prediction to the real label
#   - It adjusts its internal numbers to do better next time
#   - This repeats for every image, for 60 epochs (rounds)
#
# Key parameters:
#   model=yolo11s.pt → "small" YOLO11, pre-trained on ImageNet
#                      It already knows what objects look like.
#                      We fine-tune it to know potholes specifically.
#   epochs=60        → 60 full passes through the training data
#   imgsz=640        → resize all images to 640×640 pixels
#   batch=16         → process 16 images at a time on the GPU
#   patience=20      → stop early if no improvement for 20 epochs
#   project/name     → where to save results
#
# ⏱️  Expected time: 30-45 minutes on T4 GPU
# 💾  Weights auto-saved to Drive every epoch (see below)
# ============================================================

import os

RUN_NAME  = "pothole_yolo11s_v1"
DATA_YAML = f"{COMBINED_DIR}/data.yaml"

# Final safety check — confirm data.yaml has correct paths
with open(DATA_YAML) as f:
    content = f.read()
print("Training data.yaml:")
print(content)

# Confirm training image count one more time
import yaml
with open(DATA_YAML) as f:
    cfg = yaml.safe_load(f)
train_path = cfg['train']
n_train = len(os.listdir(train_path)) if os.path.exists(train_path) else 0
print(f"✅ Training on {n_train} images")

if n_train < 1000:
    print(f"⚠️  WARNING: Only {n_train} training images detected.")
    print("   Expected 5000+. Re-run Section 3C before continuing.")
else:
    print(f"\n🚀 Starting training — run name: {RUN_NAME}")
    print("   Watch the 'mAP50' column — it should increase over time.")
    print("   Higher mAP50 = model is getting better at finding potholes.\n")

    os.chdir(HOME)

    # !yolo task=detect mode=train \
          model=yolo11s.pt \
          data={DATA_YAML} \
          epochs=60 \
          imgsz=640 \
          batch=16 \
          patience=20 \
          plots=True \
          save=True \
          save_period=5 \
          project={HOME}/runs/detect \
          name={RUN_NAME}

    print(f"\n✅ Training complete!")

    # Immediately save to Drive
    RUN_DIR = f"{HOME}/runs/detect/{RUN_NAME}"
    save_to_drive(RUN_DIR, DRIVE_RUNS)
    print(f"\n💾 Weights saved to Google Drive: {DRIVE_RUNS}/{RUN_NAME}")
# Out:
# Training data.yaml:
# names:
# - pothole
# nc: 1
# test: /content/datasets/combined/test/images
# train: /content/datasets/combined/train/images
# val: /content/datasets/combined/valid/images
#
# ✅ Training on 5101 images
#
# 🚀 Starting training — run name: pothole_yolo11s_v1
#    Watch the 'mAP50' column — it should increase over time.
#    Higher mAP50 = model is getting better at finding potholes.
#
# New https://pypi.org/project/ultralytics/8.4.99 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.40 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# engine/trainer: task=detect, mode=train, model=yolo11s.pt, data=/content/datasets/combined/data.yaml, epochs=60, time=None, patience=20, batch=16, imgsz=640, save=True, save_period=5, cache=False, device=None, workers=8, project=/content/runs/detect, name=pothole_yolo11s_v1, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=/content/runs/detect/pothole_yolo11s_v1
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 24.9MB/s]
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   3                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   4                  -1  1    103360  ultralytics.nn.modules.block.C3k2            [128, 256, 1, False, 0.25]
#   5                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   6                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    443776  ultralytics.nn.modules.block.C3k2            [768, 256, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    127680  ultralytics.nn.modules.block.C3k2            [512, 128, 1, False]
#  17                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1    345472  ultralytics.nn.modules.block.C3k2            [384, 256, 1, False]
#  20                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  23        [16, 19, 22]  1    819795  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# YOLO11s summary: 319 layers, 9,428,179 parameters, 9,428,163 gradients, 21.5 GFLOPs
#
# Transferred 493/499 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir /content/runs/detect/pothole_yolo11s_v1', view at http://localhost:6006/
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100% 5.35M/5.35M [00:00<00:00, 94.6MB/s]
# AMP: checks passed ✅
# train: Scanning /content/datasets
weights/best.pt...
# Ultralytics 8.3.40 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 238 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 21/21 [00:09<00:00,  2.12it/s]
#                    all        666        687      0.604      0.469      0.518      0.219
# Speed: 0.3ms preprocess, 5.4ms inference, 0.0ms loss, 3.6ms postprocess per image
# Results saved to /content/runs/detect/pothole_yolo11s_v1
# 💡 Learn more at https://docs.ultralytics.com/modes/train
#
# ✅ Training complete!
# ✅ Run saved to Drive: /content/drive/MyDrive/PotholeAI/runs/pothole_yolo11s_v1
#    💾 epoch40.pt
#    💾 epoch35.pt
#    💾 epoch25.pt
#    💾 epoch15.pt
#    💾 best.pt
#    💾 epoch10.pt
#    💾 epoch0.pt
#    💾 epoch20.pt
#    💾 epoch50.pt
#    💾 epoch30.pt
#    💾 epoch55.pt
#    💾 epoch45.pt
#    💾 epoch5.pt
#    💾 last.pt
#
# 💾 Weights saved to Google Drive: /content/drive/MyDrive/PotholeAI/runs/pothole_yolo11s_v1

# %% [markdown]
# **Resume After Disconnection**

# %%
# ============================================================
# SECTION 5: HOW TO RESUME IF COLAB DISCONNECTS
# ============================================================
#
# Colab sessions can end unexpectedly. If that happens:
#
#   1. Open this notebook again
#   2. Run Sections 0, 0B, 0C only (Setup + Drive + Keys)
#   3. Run THIS cell
#   4. Then go straight to Section 6 (Evaluate)
#      OR continue training for more epochs
#
# Your weights are on Google Drive. This cell copies them
# back into Colab so you can continue exactly where you stopped.
# ============================================================

RUN_NAME = "pothole_yolo11s_v1"   # must match Section 4

last_pt = resume_from_drive(DRIVE_RUNS, RUN_NAME)

if last_pt:
    print(f"\n✅ Ready to resume training from: {last_pt}")
    print(f"\nTo continue training for more epochs, run:")
    print(f"  !yolo task=detect mode=train resume=True model={last_pt}")
    print(f"\nTo just evaluate the existing model, go to Section 6.")
else:
    print("No previous checkpoint found.")
    print("Either training hasn't started yet, or the run name is wrong.")
# Out:
# ❌ No backup found at: /content/drive/MyDrive/PotholeAI/runs/pothole_yolo11s_v1
# No previous checkpoint found.
# Either training hasn't started yet, or the run name is wrong.

# %% [markdown]
# **SESSION RECOVERY**

# %%
# ============================================================
# SESSION RECOVERY — Run this after any Colab disconnection
# ============================================================
import os, glob, yaml

# Restore basic variables
HOME         = "/content"
COMBINED_DIR = "/content/datasets/combined"
DRIVE_RUNS   = "/content/drive/MyDrive/PotholeAI/runs"
RUN_NAME     = "pothole_yolo11s_v1"
DATA_YAML    = f"{COMBINED_DIR}/data.yaml"

# Mount Drive to access saved weights
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
print("✅ Drive mounted")

# Point directly to the saved weights on Drive
# No need to re-download or re-train anything
BEST_PT  = f"{DRIVE_RUNS}/{RUN_NAME}/weights/best.pt"
RUN_DIR  = f"{DRIVE_RUNS}/{RUN_NAME}"

# Verify the weights file actually exists
if os.path.exists(BEST_PT):
    size_mb = os.path.getsize(BEST_PT) / 1e6
    print(f"✅ Model weights found: {BEST_PT}")
    print(f"   File size: {size_mb:.1f} MB")
    print(f"\n🎯 Your model results:")
    print(f"   mAP50      = 0.518  (51.8%)")
    print(f"   Precision  = 0.604  (60.4%)")
    print(f"   Recall     = 0.469  (46.9%)")
    print(f"\n✅ Ready to evaluate and run detections.")
else:
    print(f"❌ Weights not found at: {BEST_PT}")
    print(f"   Check Drive at: {DRIVE_RUNS}")
# Out:
# Mounted at /content/drive
# ✅ Drive mounted
# ✅ Model weights found: /content/drive/MyDrive/PotholeAI/runs/pothole_yolo11s_v1/weights/best.pt
#    File size: 19.2 MB
#
# 🎯 Your model results:
#    mAP50      = 0.518  (51.8%)
#    Precision  = 0.604  (60.4%)
#    Recall     = 0.469  (46.9%)
#
# ✅ Ready to evaluate and run detections.

# %% [markdown]
# **Install Packages**

# %%
# Reinstall packages — required every new Colab session
# %pip install "ultralytics<=8.3.40" supervision -q
# !yolo settings sync=False

import ultralytics
ultralytics.checks()
print("✅ Packages ready")
# Out:
# Ultralytics 8.3.40 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 50.5/112.6 GB disk)
# ✅ Packages ready

# %% [markdown]
# **VIEW TRAINING CHARTS**

# %%
# ============================================================
# VIEW TRAINING CHARTS
# ============================================================
# These charts show how your model improved over 60 epochs.
# They are saved on your Drive from the completed training run.

from IPython.display import Image as IPyImage, display
import os

charts = {
    'results.png':          'Loss Curves + mAP over 60 Epochs',
    'confusion_matrix.png': 'Confusion Matrix',
    'val_batch0_pred.jpg':  'Sample Validation Predictions',
    'PR_curve.png':         'Precision-Recall Curve',
    'F1_curve.png':         'F1 Score Curve',
}

for filename, title in charts.items():
    fpath = f"{RUN_DIR}/{filename}"
    if os.path.exists(fpath):
        print(f"\n{'='*50}")
        print(f"📊 {title}")
        print('='*50)
        display(IPyImage(filename=fpath, width=700))
    else:
        print(f"⚠️  {filename} not found")
# Out:
# ==================================================
# 📊 Loss Curves + mAP over 60 Epochs
# ==================================================
# ==================================================
# 📊 Confusion Matrix
# ==================================================
# ==================================================
# 📊 Sample Validation Predictions
# ==================================================
# ==================================================
# 📊 Precision-Recall Curve
# ==================================================
# ==================================================
# 📊 F1 Score Curve
# ==================================================

# %% [markdown]
# **Evaluate Results**

# %%
# ============================================================
# SECTION 6: EVALUATE TRAINING RESULTS
# ============================================================
#
# After training, YOLO saves these files in the run folder:
#
#   results.png       → shows how loss and accuracy changed
#                       over every epoch. Loss should go DOWN.
#                       mAP should go UP.
#
#   confusion_matrix  → a grid showing what the model gets
#                       right and wrong. Diagonal = good.
#
#   val_batch_pred    → actual images with boxes drawn on them
#                       showing what the model predicted
#
# What is mAP50?
#   mAP50 = mean Average Precision at 50% overlap threshold.
#   A predicted box counts as correct if it overlaps the
#   real box by at least 50%.
#   Score ranges from 0.0 (useless) to 1.0 (perfect).
#   A score of 0.6+ is good for a first training run.
# ============================================================

import glob

RUN_NAME = "pothole_yolo11s_v1"

# Find the run folder (handles auto-numbering like _v12, _v13)
matching = glob.glob(f"{HOME}/runs/detect/{RUN_NAME}*/")
if not matching:
    # Try Drive backup
    matching = glob.glob(f"{DRIVE_RUNS}/{RUN_NAME}*/")

if not matching:
    print(f"❌ No training run found named '{RUN_NAME}'")
    print("   Make sure Section 4 completed successfully.")
else:
    RUN_DIR = max(matching, key=os.path.getmtime)
    print(f"✅ Loading results from: {RUN_DIR}\n")
    plot_training_results(RUN_DIR)

    # Also plot custom CSV curves
    csv_path = os.path.join(RUN_DIR, 'results.csv')
    if os.path.exists(csv_path):
        print("\n📊 Detailed training curves:")
        plot_training_csv(csv_path)
# Out:
# ✅ Loading results from: /content/runs/detect/pothole_yolo11s_v1/
#
#
# 📊 Training Results: pothole_yolo11s_v1
#
# ──────────────────────────────────────────────────
# Loss Curves + mAP
# ──────────────────────────────────────────────────
# ──────────────────────────────────────────────────
# Confusion Matrix
# ──────────────────────────────────────────────────
# ──────────────────────────────────────────────────
# Confusion Matrix (Normalised)
# ──────────────────────────────────────────────────
# ──────────────────────────────────────────────────
# Sample Predictions (Batch 0)
# ──────────────────────────────────────────────────
# ──────────────────────────────────────────────────
# Sample Predictions (Batch 1)
# ──────────────────────────────────────────────────
# ──────────────────────────────────────────────────
# Precision-Recall Curve
# ──────────────────────────────────────────────────
# ──────────────────────────────────────────────────
# F1 Score Curve
# ──────────────────────────────────────────────────
# 📊 Detailed training curves:
# ✅ Custom training curves plotted

# %% [markdown]
# **Validate on Test Set**

# %%
# ============================================================
# SECTION 6B: VALIDATE ON TEST SET
# ============================================================
#
# The test set contains images the model has NEVER seen.
# Not during training. Not during validation.
# This gives us the most honest accuracy number.
#
# The key number to look for: mAP50
# A model with mAP50 = 0.65 means: when the model draws a box
# around something it thinks is a pothole, it is right 65%
# of the time AND it finds 65% of the potholes in the image.
# ============================================================

DATA_YAML = f"{COMBINED_DIR}/data.yaml"
BEST_PT   = os.path.join(RUN_DIR, 'weights', 'best.pt')

if not os.path.exists(BEST_PT):
    print(f"❌ No trained weights at: {BEST_PT}")
    print("   Run Section 4 or Section 5 first.")
else:
    print(f"✅ Evaluating: {BEST_PT}\n")

    # !yolo task=detect mode=val \
          model={BEST_PT} \
          data={DATA_YAML} \
          plots=True

    print("\n✅ Validation complete.")
    print("   Look for 'mAP50' in the table above.")
    print("   0.5+ = good  |  0.7+ = very good  |  0.85+ = excellent")
# Out:
# ✅ Evaluating: /content/runs/detect/pothole_yolo11s_v1/weights/best.pt
#
# Ultralytics 8.3.40 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 238 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
# val: Scanning /content/datasets/combined/valid/labels.cache... 666 images, 319 backgrounds, 0 corrupt: 100% 666/666 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 42/42 [00:10<00:00,  4.19it/s]
#                    all        666        687      0.603      0.467      0.516      0.217
# Speed: 0.8ms preprocess, 8.7ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val
#
# ✅ Validation complete.
#    Look for 'mAP50' in the table above.
#    0.5+ = good  |  0.7+ = very good  |  0.85+ = excellent

# %% [markdown]
#  **Run on New Images**

# %%
# ============================================================
# SECTION 7: RUN THE MODEL ON NEW ROAD IMAGES
# ============================================================
#
# This is the most exciting part.
# We take images from the test set (ones the model never saw)
# and ask the model to find potholes in them.
#
# The model draws a bounding box around each pothole it finds.
# Next to each box it shows a confidence score (0.0 to 1.0).
# For example: "pothole 0.87" means the model is 87% confident
# that what it found is a pothole.
#
# conf=0.25 means: only show detections the model is at
# least 25% confident about. Lower = shows more (including
# wrong ones). Higher = shows fewer (only very confident ones).
# ============================================================

DATA_YAML  = f"{COMBINED_DIR}/data.yaml"
BEST_PT    = os.path.join(RUN_DIR, 'weights', 'best.pt')
TEST_IMGS  = f"{COMBINED_DIR}/test/images"

import yaml
with open(DATA_YAML) as f:
    cfg = yaml.safe_load(f)
test_path = cfg.get('test', TEST_IMGS)

if not os.path.exists(BEST_PT):
    print("❌ No trained model found. Run Section 4 first.")
elif not os.path.exists(test_path):
    print(f"❌ Test images not found at: {test_path}")
else:
    os.chdir(HOME)
    print(f"🔍 Running pothole detection on test images...")
    print(f"   Model: {BEST_PT}")
    print(f"   Images: {test_path}\n")

    # !yolo task=detect mode=predict \
          model={BEST_PT} \
          conf=0.25 \
          source={test_path} \
          save=True \
          name=pothole_predictions

    # Display random sample of predictions
    pred_dirs = glob.glob(f'{HOME}/runs/detect/pothole_predictions*/')
    if pred_dirs:
        latest = max(pred_dirs, key=os.path.getmtime)
        show_random_predictions(latest, n=4)
    else:
        print("❌ No prediction output found")
# Out:
# 🔍 Running pothole detection on test images...
#    Model: /content/runs/detect/pothole_yolo11s_v1/weights/best.pt
#    Images: /content/datasets/combined/test/images
#
# Ultralytics 8.3.40 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11s summary (fused): 238 layers, 9,413,187 parameters, 0 gradients, 21.3 GFLOPs
#
# image 1/642 /content/datasets/combined/test/images/czech_Czech_000086.jpg: 640x640 1 pothole, 15.5ms
# image 2/642 /content/datasets/combined/test/images/czech_Czech_000263.jpg: 640x640 (no detections), 15.6ms
# image 3/642 /content/datasets/combined/test/images/czech_Czech_000293.jpg: 640x640 3 potholes, 15.5ms
# image 4/642 /content/datasets/combined/test/images/czech_Czech_000298.jpg: 640x640 (no detections), 15.5ms
# image 5/642 /content/datasets/combined/test/images/czech_Czech_000337.jpg: 640x640 (no detections), 15.5ms
# image 6/642 /content/datasets/combined/test/images/czech_Czech_000392.jpg: 640x640 (no detections), 15.5ms
# image 7/642 /content/datasets/combined/test/images/czech_Czech_000395.jpg: 640x640 (no detections), 15.4ms
# image 8/642 /content/datasets/combined/test/images/czech_Czech_000458.jpg: 640x640 (no detections), 15.5ms
# image 9/642 /content/datasets/combined/test/images/czech_Czech_000597.jpg: 640x640 (no detections), 15.5ms
# image 10/642 /content/datasets/combined/test/images/czech_Czech_000702.jpg: 640x640 (no detections), 15.5ms
# image 11/642 /content/datasets/combined/test/images/czech_Czech_000755.jpg: 640x640 (no detections), 15.4ms
# image 12/642 /content/datasets/combined/test/images/czech_Czech_000757.jpg: 640x640 (no detections), 15.4ms
# image 13/642 /content/datasets/combined/test/images/czech_Czech_000883.jpg: 640x640 1 pothole, 12.7ms
# image 14/642 /content/datasets/combined/test/images/czech_Czech_000920.jpg: 640x640 1 pothole, 10.8ms
# image 15/642 /content/datasets/combined/test/images/czech_Czech_001201.jpg: 640x640 (no detections), 10.9ms
# image 16/642 /content/datasets/combined/test/images/czech_Czech_001463.jpg: 640x640 1 pothole, 10.8ms
# image 17/642 /content/datasets/combined/test/images/czech_Czech_001597.jpg: 640x640 (no detections), 10.8ms
# image 18/642 /content/datasets/combined/test/images/czech_Czech_001948.jpg: 640x640 (no detections), 10.8ms
# image 19/642 /content/datasets/combined/test/images/czech_Czech_002145.jpg: 640x640 (no detections), 10.8ms
# image 20/642 /content/datasets/combined/test/images/czech_Czech_002244.jpg: 640x640 (no detections), 10.8ms
# image 21/642 /content/datasets/combined/test/images/czech_Czech_002248.jpg: 640x640 1 pothole, 10.9ms
# image 22/642 /content/datasets/combined/test/images/czech_Czech_002324.jpg: 640x640 (no detections), 10.9ms
# image 23/642 /content/datasets/combined/test/images/czech_Czech_002420.jpg: 640x640 1 pothole, 10.9ms
# image 24/642 /content/datasets/combined/test/images/czech_Czech_002527.jpg: 640x640 (no detections), 16.9ms
# image 25/642 /content/datasets/combined/test/images/czech_Czech_002792.jpg: 640x640 1 pothole, 16.5ms
# image 26/642 /content/datasets/combined/test/images/czech_Czech_002916.jpg: 640x640 (no detections), 8.5ms
# image 27/642 /content/datasets/combined/test/images/czech_Czech_003030.jpg: 640x640 (no detections), 8.8ms
# image 28/642 /content/datasets/combined/test/images/czech_Czech_003344.jpg: 640x640 (no detections), 8.7ms
# image 29/642 /content/datasets/combined/test/images/czech_Czech_003364.jpg: 640x640 (no detections), 9.5ms
# image 30/642 /content/datasets/combined/test/images/czech_Czech_003434.jpg: 640x640 (no detections), 8.8ms
# image 31/642 /content/datasets/combined/test/images/czech_Czech_003537.jpg: 640x640 1 pothole, 8.6ms
# image 32/642 /content/datasets/combined/test/images/czech_Czech_003565.jpg: 640x640 1 pothole, 8.7ms
# image 33/642 /content/datasets/combined/test/images/india_India_000011.jpg: 640x640 (no detections), 8.6ms
# image 34/642 /content/datasets/combined/test/images/india_India_000111.jpg: 640x640 (no detections), 8.7ms
# image 35/642 /content/datasets/combined/test/images/india_India_000168.jpg: 640x640 (no detections), 8.5ms
# image 36/642 /content/datasets/combined/test/images/india_India_000230.jpg: 640x640 1 pothole, 9.1ms
# image 37/642 /content/datasets/combined/test/images/india_India_000268.jpg: 640x640 1 pothole, 8.4ms
# image 38/642 /content/datasets/combined/test/images/india_India_000301.jpg: 640x640 (no detections), 8.1ms
# image 39/642 /content/datasets/combined/test/images/india_India_000338.jpg: 640x640 (no detections), 10.6ms
# image 40/642 /content/datasets/combined/test/images/india_India_000349.jpg: 640x640 (no detections), 8.0ms
# image 41/642 /content/datasets/combined/test/images/india_India_000358.jpg: 640x640 (no detections), 8.0ms
# image 42/642 /content/datasets/combined/test/images/india_India_000361.jpg: 640x640 3 potholes, 8.4ms
# image 43/642 /content/datasets/combined/test/images/india_India_000439.jpg: 640x640 4 potholes, 9.1ms
# image 44/642 /content/datasets/combined/test/images/india_India_000445.jpg: 640x640 (no detections), 8.5ms
# image 45/642 /content/datasets/combined/test/images/india_India_000456.jpg: 640x640 1 pothole, 8.4ms
# image 46/642 /content/datasets/combined/test/images/india_India_000459.jpg: 640x640 (no detections), 8.4ms
# image 47/642 /content/datasets/combined/test/images/india_India_000552.jpg: 640x640 4 potholes, 8.6ms
# image 48/642 /content/datasets/combined/test/images/india_India_000579.jpg: 640x640 1 pothole, 8.9ms
# image 49/642 /content/datasets/combined/test/images/india_India_000758.jpg: 640x640 (no detections), 9.8ms
# image 50/642 /content/datasets/combined/test/images/india_India_000765.jpg: 640x640 (no detections), 8.2ms
# image 51/642 /content/datasets/combined/test/images/india_India_000874.jpg: 640x640 (no detections), 8.0ms
# image 52/642 /content/datasets/combined/test/images/india_India_000885.jpg: 640x640 (no detections), 8.3ms
# image 53/642 /content/datasets/combined/test/images/india_India_000893.jpg: 640x640 (no detections), 8.4ms
# image 54/642 /content/datasets/combined/test/images/india_India_000921.jpg: 640x640 1 pothole, 8.3ms
# image 55/642 /content/datasets/combined/test/images/india_India_000932.jpg: 640x640 (no detections), 8.5ms
# image 56/642 /content/datasets/combined/test/images/india_India_000938.jpg: 640x640 (no detections), 10.1ms
# image 57/642 /content/datasets/combined/test/images/india_India_000942.jpg: 640x640 1 pothole, 8.4ms
# image 58/642 /content/datasets/combined/test/images/india_India_000958.jpg: 640x640 (no detections), 8.6ms
# image 59/642 /content/datasets/combined/test/images/india_India_000981.jpg: 640x640 2 potholes, 9.2ms
# image 60/642 /content/datasets/combined/test/images/india_India_000994.jpg: 640x640 2 potholes, 8.3ms
# image 61/642 /content/datasets/combined/test/images/india_India_001007.jpg: 640x640 3 potholes, 8.2ms
# image 62/642 /content/datasets/combined/test/images/india_India_001069.jpg: 640x640 2 potholes, 8.1ms
# image 63/642 /content/datasets/combined/test/images/india_India_001105.jpg: 640x640 (no detections), 7.9ms
# image 64/642 /content/datasets/combined/test/images/india_India_001114.jpg: 640x640 3 potholes, 9.0ms
# image 65/642 /content/datasets/combined/test/images/india_India_001125.jpg: 640x640 (no detections), 8.4ms
# image 66/642 /content/datasets/combined/test/images/india_India_001167.jpg: 640x640 1 pothole, 10.7ms
# image 67/642 /content/datasets/combined/test/images/india_India_001168.jpg: 640x640 (no detections), 9.1ms
# image 68/642 /content/datasets/combined/test/images/india_India_001187.jpg: 640x640 1 pothole, 8.3ms
# image 69/642 /content/datasets/combined/test/images/india_India_001220.jpg: 640x640 (no detections), 8.5ms
# image 70/642 /content/datasets/combined/test/images/india_India_001315.jpg: 640x640 (no detections), 8.4ms
# image 71/642 /content/datasets/combined/test/images/india_India_001319.jpg: 640x640 2 potholes, 8.4ms
# image 72/642 /content/datasets/combined/test/images/india_India_001392.jpg: 640x640 (no detections), 9.4ms
# image 73/642 /content/datasets/combined/test/images/india_India_001404.jpg: 640x640 (no detections), 8.5ms
# image 74/642 /content/datasets/combined/test/images/india_India_001414.jpg: 640x640 (no detections), 13.8ms
# image 75/642 /content/datasets/combined/test/images/india_India_001424.jpg: 640x640 1 pothole, 8.6ms
# image 76/642 /content/datasets/combined/test/images/india_India_001445.jpg: 640x640 (no detections), 15.7ms
# image 77/642 /content/datasets/combined/test/images/india_India_001466.jpg: 640x640 (no detections), 8.8ms
# image 78/642 /content/datasets/combined/test/images/india_India_001480.jpg: 640x640 1 pothole, 8.6ms
# image 79/642 /content/datasets/combined/test/images/india_India_001488.jpg: 640x640 (no detections), 8.7ms
# image 80/642 /content/datasets/combined/test/images/india_India_001493.jpg: 640x640 2 potholes, 9.1ms
# image 81/642 /content/datasets/combined/test/images/india_India_001524.jpg: 640x640 (no detections), 9.0ms
# image 82/642 /content/datasets/combined/test/images/india_India_001575.jpg: 640x640 (no detections), 9.2ms
# image 83/642 /content/datasets/combined/test/images/india_India_001687.jpg: 640x640 3 potholes, 8.9ms
# image 84/642 /content/datasets/combined/test/images/india_India_001717.jpg: 640x640 1 pothole, 9.0ms
# image 85/642 /content/datasets/combined/test/images/india_India_001729.jpg: 640x640 (no detections), 9.6ms
# image 86/642 /content/datasets/combined/test/images/india_India_001734.jpg: 640x640 (no detections), 8.9ms
# image 87/642 /content/datasets/combined/test/images/india_India_001737.jpg: 640x640 1 pothole, 9.8ms
# image 88/642 /content/datasets/combined/test/images/india_India_001795.jpg: 640x640 (no detections), 8.7ms
# image 89/642 /content/datasets/combined/test/images/india_India_001812.jpg: 640x640 1 pothole, 8.9ms
# image 90/642 /content/datasets/combined/test/images/india_India_001845.jpg: 640x640 (no detections), 8.7ms
# image 91/642 /content/datasets/combined/test/images/india_India_002059.jpg: 640x640 1 pothole, 9.1ms
# image 92/642 /content/datasets/combined/test/images/india_India_002069.jpg: 640x640 3 potholes, 9.2ms
# image 93/642 /content/datasets/combined/test/images/india_India_002096.jpg: 640x640 (no detections), 8.7ms
# image 94/642 /content/datasets/combined/test/images/india_India_002098.jpg: 640x640 (no detections), 8.9ms
# image 95/642 /content/datasets/combined/test/images/india_India_002126.jpg: 640x640 (no detections), 9.4ms
# image 96/642 /content/datasets/combined/test/images/india_India_002133.jpg: 640x640 1 pothole, 8.8ms
# image 97/642 /content/datasets/combined/test/images/india_India_002178.jpg: 640x640 (no detections), 9.3ms
# image 98/642 /content/datasets/combined/test/images/india_India_002184.jpg: 640x640 (no detections), 8.7ms
# image 99/642 /content/datasets/combined/test/images/india_India_002207.jpg: 640x640 1 pothole, 8.7ms
# image 100/642 /content/datasets/combined/test/images/india_India_002213.jpg: 640x640 (no detections), 9.5ms
# image 101/642 /content/datasets/combined/test/images/india_India_002235.jpg: 640x640 (no detections), 9.4ms
# image 102/642 /content/datasets/combined/test/images/india_India_002253.jpg: 640x640 2 potholes, 12.5ms
# image 103/642 /content/datasets/combined/test/images/india_India_002363.jpg: 640x640 1 pothole, 8.4ms
# image 104/642 /content/datasets/combined/test/images/india_India_002417.jpg: 640x640 (no detections), 8.3ms
# image 105/642 /content/datasets/combined/test/images/india_India_002443.jpg: 640x640 (no detections), 8.4ms
# image 106/642 /content/datasets/combined/test/images/india_India_002533.jpg: 640x640 (no detections), 8.2ms
# image 107/642 /content/datasets/combined/test/images/india_India_002582.jpg: 640x640 (no detections), 8.2ms
# image 108/642 /content/datasets/combined/test/images/india_India_002615.jpg: 640x640 (no detections), 8.5ms
# image 109/642 /content/datasets/combined/test/images/india_India_002643.jpg: 640x640 (no detections), 8.8ms
# image 110/642 /content/datasets/combined/test/images/india_India_002729.jpg: 640x640 (no detections), 8.1ms
# image 111/642 /content/datasets/combined/test/images/india_India_002748.jpg: 640x640 (no detections), 8.2ms
# image 112/642 /content/datasets/combined/test/images/india_India_002755.jpg: 640x640 (no detections), 8.0ms
# image 113/642 /content/datasets/combined/test/images/india_India_002803.jpg: 640x640 (no detections), 9.8ms
# image 114/642 /content/datasets/combined/test/images/india_India_002823.jpg: 640x640 (no detections), 7.9ms
# image 115/642 /content/datasets/combined/test/images/india_India_002824.jpg: 640x640 (no detections), 8.4ms
# image 116/642 /content/datasets/combined/test/images/india_India_002843.jpg: 640x640 (no detections), 8.7ms
# image 117/642 /content/datasets/combined/test/images/india_India_002871.jpg: 640x640 1 pothole, 10.1ms
# image 118/642 /content/datasets/combined/test/images/india_India_002890.jpg: 640x640 (no detections), 8.3ms
# image 119/642 /content/datasets/combined/test/images/india_India_002956.jpg: 640x640 1 pothole, 8.3ms
# image 120/642 /content/datasets/combined/test/images/india_India_003004.jpg: 640x640 (no detections), 8.3ms
# image 121/642 /content/datasets/combined/test/images/india_India_003006.jpg: 640x640 1 pothole, 8.6ms
# image 122/642 /content/datasets/combined/test/images/india_India_003033.jpg: 640x640 (no detections), 8.0ms
# image 123/642 /content/datasets/combined/test/images/india_India_003083.jpg: 640x640 4 potholes, 8.2ms
# image 124/642 /content/datasets/combined/test/images/india_India_003085.jpg: 640x640 1 pothole, 7.9ms
# image 125/642 /content/datasets/combined/test/images/india_India_003113.jpg: 640x640 (no detections), 8.0ms
# image 126/642 /content/datasets/combined/test/images/india_India_003120.jpg: 640x640 2 potholes, 7.9ms
# image 127/642 /content/datasets/combined/test/images/india_India_003161.jpg: 640x640 (no detections), 8.2ms
# image 128/642 /content/datasets/combined/test/images/india_India_003168.jpg: 640x640 1 pothole, 13.3ms
# image 129/642 /content/datasets/combined/test/images/india_India_003191.jpg: 640x640 (no detections), 10.8ms
# image 130/642 /content/datasets/combined/test/images/india_India_003218.jpg: 640x640 (no detections), 8.5ms
# image 131/642 /content/datasets/combined/test/images/india_India_003284.jpg: 640x640 7 potholes, 9.5ms
# image 132/642 /content/datasets/combined/test/images/india_India_003318.jpg: 640x640 1 pothole, 9.2ms
# image 133/642 /content/datasets/combined/test/images/india_India_003356.jpg: 640x640 (no detections), 9.1ms
# image 134/642 /content/datasets/combined/test/images/india_India_003362.jpg: 640x640 3 potholes, 9.0ms
# image 135/642 /content/datasets/combined/test/images/india_India_003401.jpg: 640x640 (no detections), 8.9ms
# image 136/642 /content/datasets/combined/test/images/india_India_003466.jpg: 640x640 (no detections), 9.7ms
# image 137/642 /content/datasets/combined/test/images/india_India_003538.jpg: 640x640 (no detections), 9.4ms
# image 138/642 /content/datasets/combined/test/images/india_India_003550.jpg: 640x640 (no detections), 11.8ms
# image 139/642 /content/datasets/combined/test/images/india_India_003608.jpg: 640x640 (no detections), 9.4ms
# image 140/642 /content/datasets/combined/test/images/india_India_003634.jpg: 640x640 (no detections), 9.7ms
# image 141/642 /content/datasets/combined/test/images/india_India_003645.jpg: 640x640 (no detections), 12.0ms
# image 142/642 /content/datasets/combined/test/images/india_India_003647.jpg: 640x640 (no detections), 10.4ms
# image 143/642 /content/datasets/combined/test/images/india_India_003658.jpg: 640x640 1 pothole, 8.8ms
# image 144/642 /content/datasets/combined/test/images/india_India_003739.jpg: 640x640 (no detections), 9.2ms
# image 145/642 /content/datasets/combined/test/images/india_India_003761.jpg: 640x640 2 potholes, 9.8ms
# image 146/642 /content/datasets/combined/test/images/india_India_003839.jpg: 640x640 (no detections), 9.0ms
# image 147/642 /content/datasets/combined/test/images/india_India_003872.jpg: 640x640 (no detections), 8.8ms
# image 148/642 /content/datasets/combined/test/images/india_India_003920.jpg: 640x640 (no detections), 8.7ms
# image 149/642 /content/datasets/combined/test/images/india_India_003950.jpg: 640x640 (no detections), 9.0ms
# image 150/642 /content/datasets/combined/test/images/india_India_003981.jpg: 640x640 (no detections), 9.5ms
# image 151/642 /content/datasets/combined/test/images/india_India_004029.jpg: 640x640 3 potholes, 8.9ms
# image 152/642 /content/datasets/combined/test/images/india_India_004043.jpg: 640x640 (no detections), 9.5ms
# image 153/642 /content/datasets/combined/test/images/india_India_004054.jpg: 640x640 (no detections), 9.7ms
# image 154/642 /content/datasets/combined/test/images/india_India_004073.jpg: 640x640 (no detections), 9.6ms
# image 155/642 /content/datasets/combined/test/images/india_India_004074.jpg: 640x640 (no detections), 9.3ms
# image 156/642 /content/datasets/combined/test/images/india_India_004100.jpg: 640x640 2 potholes, 9.2ms
# image 157/642 /content/datasets/combined/test/images/india_India_004104.jpg: 640x640 1 pothole, 9.1ms
# image 158/642 /content/datasets/combined/test/images/india_India_004121.jpg: 640x640 (no detections), 8.9ms
# image 159/642 /content/datasets/combined/test/images/india_India_004122.jpg: 640x640 (no detections), 8.7ms
# image 160/642 /content/datasets/combined/test/images/india_India_004193.jpg: 640x640 (no detections), 9.0ms
# image 161/642 /content/datasets/combined/test/images/india_India_004226.jpg: 640x640 (no detections), 8.5ms
# image 162/642 /content/datasets/combined/test/images/india_India_004241.jpg: 640x640 (no detections), 8.4ms
# image 163/642 /content/datasets/combined/test/images/india_India_004242.jpg: 640x640 (no detections), 10.3ms
# image 164/642 /content/datasets/combined/test/images/india_India_004430.jpg: 640x640 2 potholes, 7.6ms
# image 165/642 /content/datasets/combined/test/images/india_India_004441.jpg: 640x640 (no detections), 8.0ms
# image 166/642 /content/datasets/combined/test/images/india_India_004461.jpg: 640x640 2 potholes, 8.9ms
# image 167/642 /content/datasets/combined/test/images/india_India_004478.jpg: 640x640 (no detections), 10.0ms
# image 168/642 /content/datasets/combined/test/images/india_India_004500.jpg: 640x640 (no detections), 8.3ms
# image 169/642 /content/datasets/combined/test/images/india_India_004589.jpg: 640x640 (no detections), 8.6ms
# image 170/642 /content/datasets/combined/test/images/india_India_004632.jpg: 640x640 2 potholes, 8.2ms
# image 171/642 /content/datasets/combined/test/images/india_India_004692.jpg: 640x640 (no detections), 10.3ms
# image 172/642 /content/datasets/combined/test/images/india_India_004693.jpg: 640x640 (no detections), 8.0ms
# image 173/642 /content/datasets/combined/test/images/india_India_004695.jpg: 640x640 (no detections), 8.5ms
# image 174/642 /content/datasets/combined/test/images/india_India_004701.jpg: 640x640 3 potholes, 8.5ms
# image 175/642 /content/datasets/combined/test/images/india_India_004722.jpg: 640x640 (no detections), 8.5ms
# image 176/642 /content/datasets/combined/test/images/india_India_004750.jpg: 640x640 (no detections), 8.2ms
# image 177/642 /content/datasets/combined/test/images/india_India_004759.jpg: 640x640 2 potholes, 8.2ms
# image 178/642 /content/datasets/combined/test/images/india_India_004764.jpg: 640x640 (no detections), 8.2ms
# image 179/642 /content/datasets/combined/test/images/india_India_004770.jpg: 640x640 (no detections), 12.6ms
# image 180/642 /content/datasets/combined/test/images/india_India_004827.jpg: 640x640 (no detections), 13.4ms
# image 181/642 /content/datasets/combined/test/images/india_India_004877.jpg: 640x640 1 pothole, 8.2ms
# image 182/642 /content/datasets/combined/test/images/india_India_004916.jpg: 640x640 (no detections), 8.1ms
# image 183/642 /content/datasets/combined/test/images/india_India_004943.jpg: 640x640 (no detections), 8.9ms
# image 184/642 /content/datasets/combined/test/images/india_India_005094.jpg: 640x640 (no detections), 8.6ms
# image 185/642 /content/datasets/combined/test/images/india_India_005147.jpg: 640x640 (no detections), 9.2ms
# image 186/642 /content/datasets/combined/test/images/india_India_005151.jpg: 640x640 (no detections), 8.9ms
# image 187/642 /content/datasets/combined/test/images/india_India_005197.jpg: 640x640 4 potholes, 9.0ms
# image 188/642 /content/datasets/combined/test/images/india_India_005203.jpg: 640x640 (no detections), 9.0ms
# image 189/642 /content/datasets/combined/test/images/india_India_005231.jpg: 640x640 1 pothole, 14.3ms
# image 190/642 /content/datasets/combined/test/images/india_India_005258.jpg: 640x640 (no detections), 8.9ms
# image 191/642 /content/datasets/combined/test/images/india_India_005286.jpg: 640x640 4 potholes, 8.8ms
# image 192/642 /content/datasets/combined/test/images/india_India_005296.jpg: 640x640 (no detections), 8.4ms
# image 193/642 /content/datasets/combined/test/images/india_India_005298.jpg: 640x640 1 pothole, 9.1ms
# image 194/642 /content/datasets/combined/test/images/india_India_005319.jpg: 640x640 (no detections), 8.6ms
# image 195/642 /content/datasets/combined/test/images/india_India_005371.jpg: 640x640 (no detections), 8.7ms
# image 196/642 /content/datasets/combined/test/images/india_India_005489.jpg: 640x640 (no detections), 8.6ms
# image 197/642 /content/datasets/combined/test/images/india_India_005539.jpg: 640x640 2 potholes, 8.4ms
# image 198/642 /content/datasets/combined/test/images/india_India_005546.jpg: 640x640 (no detections), 8.8ms
# image 199/642 /content/datasets/combined/test/images/india_India_005591.jpg: 640x640 (no detections), 11.3ms
# image 200/642 /content/datasets/combined/test/images/india_India_005592.jpg: 640x640 (no detections), 8.6ms
# image 201/642 /content/datasets/combined/test/images/india_India_005601.jpg: 640x640 1 pothole, 8.1ms
# image 202/642 /content/datasets/combined/test/images/india_India_005612.jpg: 640x640 1 pothole, 8.2ms
# image 203/642 /content/datasets/combined/test/images/india_India_005613.jpg: 640x640 (no detections), 7.7ms
# image 204/642 /content/datasets/combined/test/images/india_India_005620.jpg: 640x640 (no detections), 8.6ms
# image 205/642 /content/datasets/combined/test/images/india_India_005636.jpg: 640x640 (no detections), 8.6ms
# image 206/642 /content/datasets/combined/test/images/india_India_005656.jpg: 640x640 1 pothole, 10.0ms
# image 207/642 /content/datasets/combined/test/images/india_India_005715.jpg: 640x640 (no detections), 8.7ms
# image 208/642 /content/datasets/combined/test/images/india_India_005767.jpg: 640x640 (no detections), 8.6ms
# image 209/642 /content/datasets/combined/test/images/india_India_005772.jpg: 640x640 (no detections), 8.8ms
# image 210/642 /content/datasets/combined/test/images/india_India_005781.jpg: 640x640 5 potholes, 8.9ms
# image 211/642 /content/datasets/combined/test/images/india_India_005830.jpg: 640x640 1 pothole, 8.7ms
# image 212/642 /content/datasets/combined/test/images/india_India_005856.jpg: 640x640 2 potholes, 8.4ms
# image 213/642 /content/datasets/combined/test/images/india_India_005878.jpg: 640x640 2 potholes, 8.2ms
# image 214/642 /content/datasets/combined/test/images/india_India_005890.jpg: 640x640 (no detections), 10.2ms
# image 215/642 /content/datasets/combined/test/images/india_India_005901.jpg: 640x640 (no detections), 11.5ms
# image 216/642 /content/datasets/combined/test/images/india_India_005942.jpg: 640x640 (no detections), 9.9ms
# image 217/642 /content/datasets/combined/test/images/india_India_005962.jpg: 640x640 1 pothole, 8.1ms
# image 218/642 /content/datasets/combined/test/images/india_India_005968.jpg: 640x640 1 pothole, 8.4ms
# image 219/642 /content/datasets/combined/test/images/india_India_005974.jpg: 640x640 (no detections), 9.0ms
# image 220/642 /content/datasets/combined/test/images/india_India_005986.jpg: 640x640 (no detections), 8.7ms
# image 221/642 /content/datasets/combined/test/images/india_India_005995.jpg: 640x640 1 pothole, 8.3ms
# image 222/642 /content/datasets/combined/test/images/india_India_005999.jpg: 640x640 (no detections), 8.6ms
# image 223/642 /content/datasets/combined/test/images/india_India_006035.jpg: 640x640 (no detections), 8.4ms
# image 224/642 /content/datasets/combined/test/images/india_India_006065.jpg: 640x640 (no detections), 8.3ms
# image 225/642 /content/datasets/combined/test/images/india_India_006086.jpg: 640x640 (no detections), 8.4ms
# image 226/642 /content/datasets/combined/test/images/india_India_006087.jpg: 640x640 (no detections), 8.4ms
# image 227/642 /content/datasets/combined/test/images/india_India_006098.jpg: 640x640 1 pothole, 8.3ms
# image 228/642 /content/datasets/combined/test/images/india_India_006109.jpg: 640x640 (no detections), 7.8ms
# image 229/642 /content/datasets/combined/test/images/india_India_006175.jpg: 640x640 (no detections), 8.5ms
# image 230/642 /content/datasets/combined/test/images/india_India_006257.jpg: 640x640 2 potholes, 8.6ms
# image 231/642 /content/datasets/combined/test/images/india_India_006305.jpg: 640x640 2 potholes, 8.9ms
# image 232/642 /content/datasets/combined/test/images/india_India_006336.jpg: 640x640 1 pothole, 12.1ms
# image 233/642 /content/datasets/combined/test/images/india_India_006354.jpg: 640x640 (no detections), 15.1ms
# image 234/642 /content/datasets/combined/test/images/india_India_006367.jpg: 640x640 3 potholes, 8.6ms
# image 235/642 /content/datasets/combined/test/images/india_India_006378.jpg: 640x640 (no detections), 8.9ms
# image 236/642 /content/datasets/combined/test/images/india_India_006388.jpg: 640x640 (no detections), 8.9ms
# image 237/642 /content/datasets/combined/test/images/india_India_006442.jpg: 640x640 (no detections), 9.3ms
# image 238/642 /content/datasets/combined/test/images/india_India_006488.jpg: 640x640 (no detections), 9.6ms
# image 239/642 /content/datasets/combined/test/images/india_India_006543.jpg: 640x640 (no detections), 9.1ms
# image 240/642 /content/datasets/combined/test/images/india_India_006580.jpg: 640x640 1 pothole, 9.0ms
# image 241/642 /content/datasets/combined/test/images/india_India_006588.jpg: 640x640 (no detections), 8.9ms
# image 242/642 /content/datasets/combined/test/images/india_India_006602.jpg: 640x640 (no detections), 9.1ms
# image 243/642 /content/datasets/combined/test/images/india_India_006614.jpg: 640x640 1 pothole, 9.9ms
# image 244/642 /content/datasets/combined/test/images/india_India_006640.jpg: 640x640 2 potholes, 8.9ms
# image 245/642 /content/datasets/combined/test/images/india_India_006700.jpg: 640x640 (no detections), 8.6ms
# image 246/642 /content/datasets/combined/test/images/india_India_006702.jpg: 640x640 1 pothole, 8.7ms
# image 247/642 /content/datasets/combined/test/images/india_India_006704.jpg: 640x640 (no detections), 8.5ms
# image 248/642 /content/datasets/combined/test/images/india_India_006706.jpg: 640x640 (no detections), 9.4ms
# image 249/642 /content/datasets/combined/test/images/india_India_006755.jpg: 640x640 (no detections), 8.8ms
# image 250/642 /content/datasets/combined/test/images/india_India_006770.jpg: 640x640 (no detections), 8.7ms
# image 251/642 /content/datasets/combined/test/images/india_India_006847.jpg: 640x640 1 pothole, 12.2ms
# image 252/642 /content/datasets/combined/test/images/india_India_006942.jpg: 640x640 (no detections), 9.0ms
# image 253/642 /content/datasets/combined/test/images/india_India_006950.jpg: 640x640 (no detections), 8.5ms
# image 254/642 /content/datasets/combined/test/images/india_India_007075.jpg: 640x640 (no detections), 8.4ms
# image 255/642 /content/datasets/combined/test/images/india_India_007085.jpg: 640x640 (no detections), 8.7ms
# image 256/642 /content/datasets/combined/test/images/india_India_007089.jpg: 640x640 (no detections), 8.9ms
# image 257/642 /content/datasets/combined/test/images/india_India_007112.jpg: 640x640 (no detections), 10.7ms
# image 258/642 /content/datasets/combined/test/images/india_India_007123.jpg: 640x640 2 potholes, 8.6ms
# image 259/642 /content/datasets/combined/test/images/india_India_007198.jpg: 640x640 (no detections), 8.7ms
# image 260/642 /content/datasets/combined/test/images/india_India_007252.jpg: 640x640 1 pothole, 8.6ms
# image 261/642 /content/datasets/combined/test/images/india_India_007299.jpg: 640x640 4 potholes, 8.8ms
# image 262/642 /content/datasets/combined/test/images/india_India_007309.jpg: 640x640 1 pothole, 9.6ms
# image 263/642 /content/datasets/combined/test/images/india_India_007364.jpg: 640x640 (no detections), 9.1ms
# image 264/642 /content/datasets/combined/test/images/india_India_007442.jpg: 640x640 (no detections), 8.5ms
# image 265/642 /content/datasets/combined/test/images/india_India_007498.jpg: 640x640 (no detections), 8.8ms
# image 266/642 /content/datasets/combined/test/images/india_India_007499.jpg: 640x640 (no detections), 9.3ms
# image 267/642 /content/datasets/combined/test/images/india_India_007517.jpg: 640x640 (no detections), 8.8ms
# image 268/642 /content/datasets/combined/test/images/india_India_007642.jpg: 640x640 (no detections), 10.8ms
# image 269/642 /content/datasets/combined/test/images/india_India_007672.jpg: 640x640 1 pothole, 8.4ms
# image 270/642 /content/datasets/combined/test/images/india_India_007713.jpg: 640x640 1 pothole, 8.1ms
# image 271/642 /content/datasets/combined/test/images/india_India_007722.jpg: 640x640 1 pothole, 8.5ms
# image 272/642 /content/datasets/combined/test/images/india_India_007723.jpg: 640x640 3 potholes, 8.2ms
# image 273/642 /content/datasets/combined/test/images/india_India_007728.jpg: 640x640 (no detections), 8.4ms
# image 274/642 /content/datasets/combined/test/images/india_India_007732.jpg: 640x640 (no detections), 9.3ms
# image 275/642 /content/datasets/combined/test/images/india_India_007748.jpg: 640x640 (no detections), 8.4ms
# image 276/642 /content/datasets/combined/test/images/india_India_007781.jpg: 640x640 5 potholes, 8.1ms
# image 277/642 /content/datasets/combined/test/images/india_India_007795.jpg: 640x640 (no detections), 14.0ms
# image 278/642 /content/datasets/combined/test/images/india_India_007830.jpg: 640x640 (no detections), 9.6ms
# image 279/642 /content/datasets/combined/test/images/india_India_007850.jpg: 640x640 (no detections), 8.1ms
# image 280/642 /content/datasets/combined/test/images/india_India_007856.jpg: 640x640 (no detections), 8.2ms
# image 281/642 /content/datasets/combined/test/images/india_India_007859.jpg: 640x640 (no detections), 8.7ms
# image 282/642 /content/datasets/combined/test/images/india_India_007900.jpg: 640x640 2 potholes, 8.9ms
# image 283/642 /content/datasets/combined/test/images/india_India_007962.jpg: 640x640 (no detections), 8.2ms
# image 284/642 /content/datasets/combined/test/images/india_India_007966.jpg: 640x640 (no detections), 8.6ms
# image 285/642 /content/datasets/combined/test/images/india_India_007991.jpg: 640x640 (no detections), 8.5ms
# image 286/642 /content/datasets/combined/test/images/india_India_008015.jpg: 640x640 (no detections), 14.0ms
# image 287/642 /content/datasets/combined/test/images/india_India_008049.jpg: 640x640 (no detections), 9.7ms
# image 288/642 /content/datasets/combined/test/images/india_India_008084.jpg: 640x640 (no detections), 8.3ms
# image 289/642 /content/datasets/combined/test/images/india_India_008087.jpg: 640x640 (no detections), 7.9ms
# image 290/642 /content/datasets/combined/test/images/india_India_008198.jpg: 640x640 (no detections), 8.0ms
# image 291/642 /content/datasets/combined/test/images/india_India_008279.jpg: 640x640 1 pothole, 8.0ms
# image 292/642 /content/datasets/combined/test/images/india_India_008285.jpg: 640x640 2 potholes, 7.4ms
# image 293/642 /content/datasets/combined/test/images/india_India_008382.jpg: 640x640 (no detections), 10.6ms
# image 294/642 /content/datasets/combined/test/images/india_India_008440.jpg: 640x640 1 pothole, 8.2ms
# image 295/642 /content/datasets/combined/test/images/india_India_008465.jpg: 640x640 (no detections), 8.1ms
# image 296/642 /content/datasets/combined/test/images/india_India_008480.jpg: 640x640 (no detections), 8.4ms
# image 297/642 /content/datasets/combined/test/images/india_India_008517.jpg: 640x640 (no detections), 8.1ms
# image 298/642 /content/datasets/combined/test/images/india_India_008518.jpg: 640x640 (no detections), 8.1ms
# image 299/642 /content/datasets/combined/test/images/india_India_008563.jpg: 640x640 (no detections), 8.2ms
# image 300/642 /content/datasets/combined/test/images/india_India_008577.jpg: 640x640 (no detections), 7.9ms
# image 301/642 /content/datasets/combined/test/images/india_India_008643.jpg: 640x640 (no detections), 8.5ms
# image 302/642 /content/datasets/combined/test/images/india_India_008658.jpg: 640x640 (no detections), 8.1ms
# image 303/642 /content/datasets/combined/test/images/india_India_008722.jpg: 640x640 (no detections), 8.2ms
# image 304/642 /content/datasets/combined/test/images/india_India_008757.jpg: 640x640 (no detections), 8.1ms
# image 305/642 /content/datasets/combined/test/images/india_India_008780.jpg: 640x640 (no detections), 8.7ms
# image 306/642 /content/datasets/combined/test/images/india_India_008858.jpg: 640x640 (no detections), 8.1ms
# image 307/642 /content/datasets/combined/test/images/india_India_008933.jpg: 640x640 (no detections), 8.3ms
# image 308/642 /content/datasets/combined/test/images/india_India_008948.jpg: 640x640 3 potholes, 8.3ms
# image 309/642 /content/datasets/combined/test/images/india_India_008950.jpg: 640x640 3 potholes, 8.3ms
# image 310/642 /content/datasets/combined/test/images/india_India_008953.jpg: 640x640 (no detections), 11.3ms
# image 311/642 /content/datasets/combined/test/images/india_India_008991.jpg: 640x640 (no detections), 8.1ms
# image 312/642 /content/datasets/combined/test/images/india_India_009002.jpg: 640x640 (no detections), 8.4ms
# image 313/642 /content/datasets/combined/test/images/india_India_009011.jpg: 640x640 2 potholes, 8.3ms
# image 314/642 /content/datasets/combined/test/images/india_India_009041.jpg: 640x640 1 pothole, 8.9ms
# image 315/642 /content/datasets/combined/test/images/india_India_009097.jpg: 640x640 2 potholes, 8.3ms
# image 316/642 /content/datasets/combined/test/images/india_India_009139.jpg: 640x640 (no detections), 9.0ms
# image 317/642 /content/datasets/combined/test/images/india_India_009144.jpg: 640x640 1 pothole, 9.5ms
# image 318/642 /content/datasets/combined/test/images/india_India_009268.jpg: 640x640 (no detections), 8.8ms
# image 319/642 /content/datasets/combined/test/images/india_India_009318.jpg: 640x640 2 potholes, 13.8ms
# image 320/642 /content/datasets/combined/test/images/india_India_009325.jpg: 640x640 (no detections), 12.4ms
# image 321/642 /content/datasets/combined/test/images/india_India_009349.jpg: 640x640 (no detections), 8.8ms
# image 322/642 /content/datasets/combined/test/images/india_India_009359.jpg: 640x640 1 pothole, 8.8ms
# image 323/642 /content/datasets/combined/test/images/india_India_009377.jpg: 640x640 1 pothole, 10.5ms
# image 324/642 /content/datasets/combined/test/images/india_India_009430.jpg: 640x640 2 potholes, 8.0ms
# image 325/642 /content/datasets/combined/test/images/india_India_009448.jpg: 640x640 1 pothole, 8.2ms
# image 326/642 /content/datasets/combined/test/images/india_India_009458.jpg: 640x640 1 pothole, 8.2ms
# image 327/642 /content/datasets/combined/test/images/india_India_009522.jpg: 640x640 (no detections), 8.2ms
# image 328/642 /content/datasets/combined/test/images/india_India_009544.jpg: 640x640 (no detections), 8.3ms
# image 329/642 /content/datasets/combined/test/images/india_India_009557.jpg: 640x640 (no detections), 8.2ms
# image 330/642 /content/datasets/combined/test/images/india_India_009586.jpg: 640x640 (no detections), 7.8ms
# image 331/642 /content/datasets/combined/test/images/india_India_009656.jpg: 640x640 2 potholes, 8.6ms
# image 332/642 /content/datasets/combined/test/images/india_India_009688.jpg: 640x640 (no detections), 8.1ms
# image 333/642 /content/datasets/combined/test/images/india_India_009722.jpg: 640x640 (no detections), 7.8ms
# image 334/642 /content/datasets/combined/test/images/india_India_009745.jpg: 640x640 (no detections), 8.3ms
# image 335/642 /content/datasets/combined/test/images/india_India_009751.jpg: 640x640 (no detections), 8.1ms
# image 336/642 /content/datasets/combined/test/images/india_India_009823.jpg: 640x640 (no detections), 7.9ms
# image 337/642 /content/datasets/combined/test/images/india_India_009830.jpg: 640x640 (no detections), 9.8ms
# image 338/642 /content/datasets/combined/test/images/india_India_009850.jpg: 640x640 (no detections), 8.2ms
# image 339/642 /content/datasets/combined/test/images/japan_Japan_000037.jpg: 640x640 (no detections), 8.2ms
# image 340/642 /content/datasets/combined/test/images/japan_Japan_000074.jpg: 640x640 2 potholes, 7.9ms
# image 341/642 /content/datasets/combined/test/images/japan_Japan_000126.jpg: 640x640 (no detections), 8.2ms
# image 342/642 /content/datasets/combined/test/images/japan_Japan_000310.jpg: 640x640 (no detections), 10.6ms
# image 343/642 /content/datasets/combined/test/images/japan_Japan_000362.jpg: 640x640 1 pothole, 15.2ms
# image 344/642 /content/datasets/combined/test/images/japan_Japan_000368.jpg: 640x640 (no detections), 8.1ms
# image 345/642 /content/datasets/combined/test/images/japan_Japan_000396.jpg: 640x640 1 pothole, 8.2ms
# image 346/642 /content/datasets/combined/test/images/japan_Japan_000456.jpg: 640x640 (no detections), 8.1ms
# image 347/642 /content/datasets/combined/test/images/japan_Japan_000520.jpg: 640x640 (no detections), 8.0ms
# image 348/642 /content/datasets/combined/test/images/japan_Japan_000620.jpg: 640x640 (no detections), 8.7ms
# image 349/642 /content/datasets/combined/test/images/japan_Japan_000633.jpg: 640x640 (no detections), 13.7ms
# image 350/642 /content/datasets/combined/test/images/japan_Japan_000666.jpg: 640x640 (no detections), 8.8ms
# image 351/642 /content/datasets/combined/test/images/japan_Japan_000802.jpg: 640x640 1 pothole, 9.2ms
# image 352/642 /content/datasets/combined/test/images/japan_Japan_000884.jpg: 640x640 (no detections), 9.0ms
# image 353/642 /content/datasets/combined/test/images/japan_Japan_000891.jpg: 640x640 (no detections), 9.2ms
# image 354/642 /content/datasets/combined/test/images/japan_Japan_000902.jpg: 640x640 2 potholes, 8.5ms
# image 355/642 /content/datasets/combined/test/images/japan_Japan_000917.jpg: 640x640 1 pothole, 9.0ms
# image 356/642 /content/datasets/combined/test/images/japan_Japan_000934.jpg: 640x640 1 pothole, 8.4ms
# image 357/642 /content/datasets/combined/test/images/japan_Japan_000935.jpg: 640x640 (no detections), 8.5ms
# image 358/642 /content/datasets/combined/test/images/japan_Japan_001027.jpg: 640x640 2 potholes, 8.8ms
# image 359/642 /content/datasets/combined/test/images/japan_Japan_001075.jpg: 640x640 (no detections), 8.6ms
# image 360/642 /content/datasets/combined/test/images/japan_Japan_001089.jpg: 640x640 (no detections), 8.7ms
# image 361/642 /content/datasets/combined/test/images/japan_Japan_001106.jpg: 640x640 (no detections), 8.5ms
# image 362/642 /content/datasets/combined/test/images/japan_Japan_001173.jpg: 640x640 2 potholes, 8.6ms
# image 363/642 /content/datasets/combined/test/images/japan_Japan_001265.jpg: 640x640 1 pothole, 8.6ms
# image 364/642 /content/datasets/combined/test/images/japan_Japan_001266.jpg: 640x640 (no detections), 8.9ms
# image 365/642 /content/datasets/combined/test/images/japan_Japan_001319.jpg: 640x640 2 potholes, 8.7ms
# image 366/642 /content/datasets/combined/test/images/japan_Japan_001327.jpg: 640x640 1 pothole, 8.5ms
# image 367/642 /content/datasets/combined/test/images/japan_Japan_001396.jpg: 640x640 (no detections), 11.6ms
# image 368/642 /content/datasets/combined/test/images/japan_Japan_001450.jpg: 640x640 (no detections), 8.4ms
# image 369/642 /content/datasets/combined/test/images/japan_Japan_001541.jpg: 640x640 1 pothole, 8.2ms
# image 370/642 /content/datasets/combined/test/images/japan_Japan_001575.jpg: 640x640 1 pothole, 8.2ms
# image 371/642 /content/datasets/combined/test/images/japan_Japan_001613.jpg: 640x640 1 pothole, 8.5ms
# image 372/642 /content/datasets/combined/test/images/japan_Japan_001742.jpg: 640x640 (no detections), 9.2ms
# image 373/642 /content/datasets/combined/test/images/japan_Japan_001802.jpg: 640x640 (no detections), 9.9ms
# image 374/642 /content/datasets/combined/test/images/japan_Japan_001881.jpg: 640x640 (no detections), 9.0ms
# image 375/642 /content/datasets/combined/test/images/japan_Japan_001916.jpg: 640x640 1 pothole, 8.2ms
# image 376/642 /content/datasets/combined/test/images/japan_Japan_001979.jpg: 640x640 (no detections), 8.3ms
# image 377/642 /content/datasets/combined/test/images/japan_Japan_002023.jpg: 640x640 (no detections), 9.0ms
# image 378/642 /content/datasets/combined/test/images/japan_Japan_002088.jpg: 640x640 (no detections), 8.6ms
# image 379/642 /content/datasets/combined/test/images/japan_Japan_002106.jpg: 640x640 (no detections), 8.4ms
# image 380/642 /content/datasets/combined/test/images/japan_Japan_002153.jpg: 640x640 (no detections), 8.5ms
# image 381/642 /content/datasets/combined/test/images/japan_Japan_002154.jpg: 640x640 2 potholes, 8.4ms
# image 382/642 /content/datasets/combined/test/images/japan_Japan_002167.jpg: 640x640 (no detections), 8.5ms
# image 383/642 /content/datasets/combined/test/images/japan_Japan_002344.jpg: 640x640 (no detections), 8.4ms
# image 384/642 /content/datasets/combined/test/images/japan_Japan_002377.jpg: 640x640 1 pothole, 8.6ms
# image 385/642 /content/datasets/combined/test/images/japan_Japan_002396.jpg: 640x640 2 potholes, 8.7ms
# image 386/642 /content/datasets/combined/test/images/japan_Japan_002422.jpg: 640x640 (no detections), 8.2ms
# image 416/642 /content/datasets/combined/test/images/japan_Japan_004081.jpg: 640x640 2 potholes, 15.5ms
# image 417/642 /content/datasets/combined/test/images/japan_Japan_004114.jpg: 640x640 (no detections), 19.8ms
# image 418/642 /content/datasets/combined/test/images/japan_Japan_004136.jpg: 640x640 2 potholes, 12.1ms
# image 419/642 /content/datasets/combined/test/images/japan_Japan_004234.jpg: 640x640 1 pothole, 9.1ms
# image 420/642 /content/datasets/combined/test/images/japan_Japan_004342.jpg: 640x640 1 pothole, 9.5ms
# image 421/642 /content/datasets/combined/test/images/japan_Japan_004347.jpg: 640x640 (no detections), 8.9ms
# image 422/642 /content/datasets/combined/test/images/japan_Japan_004440.jpg: 640x640 1 pothole, 9.2ms
# image 423/642 /content/datasets/combined/test/images/japan_Japan_004514.jpg: 640x640 (no detections), 8.9ms
# image 424/642 /content/datasets/combined/test/images/japan_Japan_004524.jpg: 640x640 (no detections), 8.7ms
# image 425/642 /content/datasets/combined/test/images/japan_Japan_004623.jpg: 640x640 4 potholes, 8.5ms
# image 426/642 /content/datasets/combined/test/images/japan_Japan_004625.jpg: 640x640 (no detections), 11.2ms
# image 427/642 /content/datasets/combined/test/images/japan_Japan_004631.jpg: 640x640 3 potholes, 8.5ms
# image 428/642 /content/datasets/combined/test/images/japan_Japan_004643.jpg: 640x640 (no detections), 8.5ms
# image 429/642 /content/datasets/combined/test/images/japan_Japan_004716.jpg: 640x640 1 pothole, 8.3ms
# image 430/642 /content/datasets/combined/test/images/japan_Japan_004824.jpg: 640x640 (no detections), 8.2ms
# image 431/642 /content/datasets/combined/test/images/japan_Japan_004865.jpg: 640x640 (no detections), 13.9ms
# image 432/642 /content/datasets/combined/test/images/japan_Japan_004900.jpg: 640x640 (no detections), 8.3ms
# image 433/642 /content/datasets/combined/test/images/japan_Japan_004994.jpg: 640x640 1 pothole, 8.3ms
# image 434/642 /content/datasets/combined/test/images/japan_Japan_004999.jpg: 640x640 (no detections), 8.7ms
# image 435/642 /content/datasets/combined/test/images/japan_Japan_005052.jpg: 640x640 (no detections), 8.5ms
# image 436/642 /content/datasets/combined/test/images/japan_Japan_005055.jpg: 640x640 (no detections), 8.5ms
# image 437/642 /content/datasets/combined/test/images/japan_Japan_005099.jpg: 640x640 2 potholes, 8.6ms
# image 438/642 /content/datasets/combined/test/images/japan_Japan_005112.jpg: 640x640 (no detections), 9.3ms
# image 439/642 /content/datasets/combined/test/images/japan_Japan_005274.jpg: 640x640 (no detections), 12.7ms
# image 440/642 /content/datasets/combined/test/images/japan_Japan_005289.jpg: 640x640 2 potholes, 14.6ms
# image 441/642 /content/datasets/combined/test/images/japan_Japan_005304.jpg: 640x640 2 potholes, 8.9ms
# image 442/642 /content/datasets/combined/test/images/japan_Japan_005320.jpg: 640x640 1 pothole, 8.3ms
# image 443/642 /content/datasets/combined/test/images/japan_Japan_005345.jpg: 640x640 (no detections), 8.6ms
# image 444/642 /content/datasets/combined/test/images/japan_Japan_005522.jpg: 640x640 (no detections), 8.5ms
# image 445/642 /content/datasets/combined/test/images/japan_Japan_005578.jpg: 640x640 3 potholes, 8.7ms
# image 446/642 /content/datasets/combined/test/images/japan_Japan_005590.jpg: 640x640 (no detections), 8.3ms
# image 447/642 /content/datasets/combined/test/images/japan_Japan_005593.jpg: 640x640 (no detections), 9.3ms
# image 448/642 /content/datasets/combined/test/images/japan_Japan_005608.jpg: 640x640 (no detections), 8.3ms
# image 449/642 /content/datasets/combined/test/images/japan_Japan_005627.jpg: 640x640 (no detections), 8.3ms
# ...
# image 508/642 /content/datasets/combined/test/images/japan_Japan_008418.jpg: 640x640 (no detections), 11.2ms
# image 509/642 /content/datasets/combined/test/images/japan_Japan_008438.jpg: 640x640 (no detections), 10.6ms
# image 510/642 /content/datasets/combined/test/images/japan_Japan_008514.jpg: 640x640 2 potholes, 10.8ms
# image 511/642 /content/datasets/combined/test/images/japan_Japan_008541.jpg: 640x640 (no detections), 10.7ms
# image 512/642 /content/datasets/combined/test/images/japan_Japan_008628.jpg: 640x640 (no detections), 10.9ms
# image 513/642 /content/datasets/combined/test/images/japan_Japan_008630.jpg: 640x640 2 potholes, 10.9ms
# image 514/642 /content/datasets/combined/test/images/japan_Japan_008649.jpg: 640x640 1 pothole, 11.6ms
# image 515/642 /content/datasets/combined/test/images/japan_Japan_008676.jpg: 640x640 (no detections), 11.6ms
# image 516/642 /content/datasets/combined/test/images/japan_Japan_008817.jpg: 640x640 (no detections), 10.9ms
# image 517/642 /content/datasets/combined/test/images/japan_Japan_008908.jpg: 640x640 1 pothole, 11.2ms
# image 518/642 /content/datasets/combined/test/images/japan_Japan_008925.jpg: 640x640 1 pothole, 14.1ms
# image 519/642 /content/datasets/combined/test/images/japan_Japan_009011.jpg: 640x640 (no detections), 13.1ms
# image 520/642 /content/datasets/combined/test/images/japan_Japan_009089.jpg: 640x640 (no detections), 14.3ms
# image 521/642 /content/datasets/combined/test/images/japan_Japan_009115.jpg: 640x640 (no detections), 16.2ms
# image 522/642 /content/datasets/combined/test/images/japan_Japan_009127.jpg: 640x640 (no detections), 12.9ms
# image 523/642 /content/datasets/combined/test/images/japan_Japan_009142.jpg: 640x640 (no detections), 13.3ms
# image 524/642 /content/datasets/combined/test/images/japan_Japan_009176.jpg: 640x640 1 pothole, 11.5ms
# image 525/642 /content/datasets/combined/test/images/japan_Japan_009179.jpg: 640x640 3 potholes, 15.1ms
# image 526/642 /content/datasets/combined/test/images/japan_Japan_009275.jpg: 640x640 (no detections), 19.4ms
# image 527/642 /content/datasets/combined/test/images/japan_Japan_009321.jpg: 640x640 (no detections), 11.7ms
# image 528/642 /content/datasets/combined/test/images/japan_Japan_009396.jpg: 640x640 (no detections), 17.3ms
# image 529/642 /content/datasets/combined/test/images/japan_Japan_009398.jpg: 640x640 1 pothole, 13.5ms
# image 530/642 /content/datasets/combined/test/images/japan_Japan_009413.jpg: 640x640 2 potholes, 11.7ms
# image 531/642 /content/datasets/combined/test/images/japan_Japan_009490.jpg: 640x640 1 pothole, 11.9ms
# image 619/642 /content/datasets/combined/test/images/kenya_IMG_20241223_124730_jpg.rf.b6f73c67e54a4d33d39df0e232a5f95f.jpg: 640x640 1 pothole, 8.8ms
# image 620/642 /content/datasets/combined/test/images/kenya_IMG_20241223_124732_jpg.rf.bfa5133b5972689508e32546759cbb22.jpg: 640x640 1 pothole, 13.2ms
# image 621/642 /content/datasets/combined/test/images/kenya_IMG_20241223_124734_jpg.rf.f45e3c80d9a8513fd6edb1d4bf7d1b9b.jpg: 640x640 3 potholes, 8.8ms
# image 622/642 /content/datasets/combined/test/images/kenya_IMG_20241223_124927_jpg.rf.7533d31f3e831d06fd9b2dbae8b18e91.jpg: 640x640 2 potholes, 8.7ms
# image 623/642 /content/datasets/combined/test/images/kenya_IMG_20241223_124953_jpg.rf.7a60a53cb3a4529454b9da650e7489bd.jpg: 640x640 (no detections), 8.7ms
# image 624/642 /content/datasets/combined/test/images/kenya_IMG_20241223_125046_jpg.rf.f6239d0089ae418f3fc3de1b5af9ed71.jpg: 640x640 1 pothole, 8.7ms
# image 625/642 /content/datasets/combined/test/images/kenya_IMG_20241223_125053_jpg.rf.f90eb46f5b16592063f8886d153aaa04.jpg: 640x640 3 potholes, 8.7ms
# image 626/642 /content/datasets/combined/test/images/kenya_IMG_20241223_125057_jpg.rf.664fe6e27fe8a434d7f07c4863cf3bb7.jpg: 640x640 (no detections), 8.8ms
# image 627/642 /content/datasets/combined/test/images/kenya_IMG_20241223_125110_jpg.rf.bc5f638a0ee2c1111426562331b3a221.jpg: 640x640 (no detections), 8.7ms
# image 628/642 /content/datasets/combined/test/images/kenya_IMG_20241223_125111_jpg.rf.6a4294ce0fe061c6f1cab441d122b05e.jpg: 640x640 (no detections), 8.0ms
# image 629/642 /content/datasets/combined/test/images/kenya_IMG_20241223_125127_jpg.rf.9d50c35ed5434e9e2da6171160c12e83.jpg: 640x640 (no detections), 8.4ms
# image 630/642 /content/datasets/combined/test/images/kenya_IMG_20241223_125212_jpg.rf.62902883a048364537230f6e1b5baa77.jpg: 640x640 (no detections), 8.4ms
# image 631/642 /content/datasets/combined/test/images/kenya_IMG_20241223_125340_jpg.rf.f0953325a372d87ac4376560dc7bd319.jpg: 640x640 2 potholes, 9.0ms
# image 632/642 /content/datasets/combined/test/images/kenya_IMG_20241223_125356_jpg.rf.2b540ec210250707d73fe25153ae398b.jpg: 640x640 (no detections), 9.0ms
# image 633/642 /content/datasets/combined/test/images/kenya_IMG_20241223_125605_jpg.rf.4129ce207ddd2dd919a78f8e4f91e37b.jpg: 640x640 2 potholes, 8.7ms
# image 634/642 /content/datasets/combined/test/images/kenya_IMG_20241223_125650_jpg.rf.1dbb40eca98ba75ffd908ee88a936117.jpg: 640x640 3 potholes, 8.6ms
# image 635/642 /content/datasets/combined/test/images/kenya_IMG_20241223_125933_jpg.rf.ce36ed183f06064b064a0d5b7c984d1c.jpg: 640x640 (no detections), 8.9ms
# image 636/642 /content/datasets/combined/test/images/kenya_IMG_20241223_130013_jpg.rf.4b892ff4bc151f529034d0dbe021bfcf.jpg: 640x640 1 pothole, 8.6ms
# image 637/642 /content/datasets/combined/test/images/kenya_IMG_20241223_133950_jpg.rf.357ec17697bf34b8656b8ceeab003573.jpg: 640x640 (no detections), 8.7ms
# image 638/642 /content/datasets/combined/test/images/kenya_IMG_20241223_134001_jpg.rf.933c330f91a7c7a8cdb9b7b055d2b28a.jpg: 640x640 4 potholes, 8.9ms
# image 639/642 /content/datasets/combined/test/images/kenya_IMG_20241223_134429_jpg.rf.900430f979ab02e81994f397e06b8e6e.jpg: 640x640 3 potholes, 8.9ms
# image 640/642 /content/datasets/combined/test/images/kenya_IMG_20241223_134828_jpg.rf.e393db55a2518baa6046298250c5835c.jpg: 640x640 2 potholes, 8.3ms
# image 641/642 /content/datasets/combined/test/images/kenya_IMG_20241223_135111_jpg.rf.5e8f50ae0605b24d5194738b8a009a98.jpg: 640x640 1 pothole, 8.6ms
# image 642/642 /content/datasets/combined/test/images/kenya_IMG_20241223_135236_jpg.rf.c5c4a7518be4d34bc90a7d9f7c4af9de.jpg: 640x640 1 pothole, 8.0ms
# Speed: 3.1ms preprocess, 10.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/pothole_predictions
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
#
# 🔍 Showing 4 random detections from
#
#   japan_Japan_006052.jpg
#   czech_Czech_000458.jpg
#   india_India_001717.jpg
#   kenya_IMG_20241223_130013_jpg.rf.4b892ff4bc151f529034d0dbe021bfcf.jpg

# %% [markdown]
# **Save Everything to Drive**

# %%
# ============================================================
# SECTION 7B: SAVE FINAL MODEL TO GOOGLE DRIVE
# ============================================================
#
# This saves your best trained model weights to Google Drive
# so you never lose them after this Colab session ends.
#
# Your model is saved at:
#   /content/drive/MyDrive/PotholeAI/runs/pothole_yolo11s_v1/
#       weights/
#           best.pt  ← use this for predictions (highest mAP)
#           last.pt  ← use this to resume training
# ============================================================

save_to_drive(RUN_DIR, DRIVE_RUNS)

print(f"\n🎉 Your pothole detection model is saved to Google Drive!")
print(f"   Location: {DRIVE_RUNS}/{RUN_NAME}/")
print(f"\n   To use this model on new images anytime:")
print(f"   model = YOLO('{DRIVE_RUNS}/{RUN_NAME}/weights/best.pt')")
print(f"   results = model.predict('your_road_image.jpg', conf=0.25)")
# Out:
# ✅ Run saved to Drive: /content/drive/MyDrive/PotholeAI/runs/pothole_yolo11s_v1
#    💾 epoch40.pt
#    💾 epoch35.pt
#    💾 epoch25.pt
#    💾 epoch15.pt
#    💾 best.pt
#    💾 epoch10.pt
#    💾 epoch0.pt
#    💾 epoch20.pt
#    💾 epoch50.pt
#    💾 epoch30.pt
#    💾 epoch55.pt
#    💾 epoch45.pt
#    💾 epoch5.pt
#    💾 last.pt
#
# 🎉 Your pothole detection model is saved to Google Drive!
#    Location: /content/drive/MyDrive/PotholeAI/runs/pothole_yolo11s_v1/
#
#    To use this model on new images anytime:
#    model = YOLO('/content/drive/MyDrive/PotholeAI/runs/pothole_yolo11s_v1/weights/best.pt')
#    results = model.predict('your_road_image.jpg', conf=0.25)
